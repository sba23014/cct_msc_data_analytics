# %%
import pandas as pd

# %%
data_frame = pd.read_csv('./property-price-registry-2010-2018.csv')

# %%
data_frame
# Out:
#          SALE_DATE                                         ADDRESS  \
# 0       2010-01-01          5 Braemor Drive, Churchtown, Co.Dublin
# 1       2010-01-03  134 Ashewood Walk, Summerhill Lane, Portlaoise
# 2       2010-01-04             1 Meadow Avenue, Dundrum, Dublin 14
# 3       2010-01-04                         1 The Haven, Mornington
# 4       2010-01-04                   11 Melville Heights, Kilkenny
# ...            ...                                             ...
# 476740  2021-05-28                GRANGE STORES, GRANGE, MULLINGAR
# 476741  2021-05-28               MAIN STREET, LOWER BORRIS, BORRIS
# 476742  2021-05-28                         MULTYFARNHAM, WESTMEATH
# 476743  2021-05-28             NO 2 RIVERLODGE, SHRONE, GLENGARIFF
# 476744  2021-05-28                         RABANE, KILL, COOTEHILL
#
#        POSTAL_CODE     COUNTY  SALE_PRICE  IF_MARKET_PRICE  IF_VAT_EXCLUDED  \
# 0              NaN     Dublin    343000.0                0                0
# ...

# %%
data_frame.columns
# Out:
# Index(['SALE_DATE', 'ADDRESS', 'POSTAL_CODE', 'COUNTY', 'SALE_PRICE',
#        'IF_MARKET_PRICE', 'IF_VAT_EXCLUDED', 'PROPERTY_DESC',
#        'PROPERTY_SIZE_DESC'],
#       dtype='object')

# %%
# district 1 20 houses 0.5 mln -> 10 mln

# %%
# 20 houses 0.5 mln -> 0.5 mln average
data_frame['COLUMN_NUMBER'] = [number for number in range(len(data_frame.index))]

# %%
# Out:
#          SALE_DATE                                        ADDRESS POSTAL_CODE  \
# 0       2010-01-01         5 Braemor Drive, Churchtown, Co.Dublin         NaN
# 2       2010-01-04            1 Meadow Avenue, Dundrum, Dublin 14         NaN
# 5       2010-01-04                 12 Sallymount Avenue, Ranelagh         NaN
# 11      2010-01-04      206 Philipsburgh Avenue, Marino, Dublin 3         NaN
# 12      2010-01-04         22 Laverna Way, Castleknock, Dublin 15         NaN
# ...            ...                                            ...         ...
# 476707  2021-05-28      116A CHERRYWOOD DR, CLONDALKIN, DUBLIN 22   Dublin 22
# 476713  2021-05-28         189 CROSBIES YARD, OSSORY RD, DUBLIN 1    Dublin 1
# 476720  2021-05-28     28 CORDUFF GARDENS, BLANCHARDSTOWN, DUBLIN   Dublin 15
# 476726  2021-05-28  35 The Turnstone, Barnageeragh Cove, Skerries         NaN
# 476731  2021-05-28                69B ORWELL PARK RISE, DUBLIN 6W         NaN
#
# ...

# %%
totals = data_frame.groupby("COUNTY").agg({"COLUMN_NUMBER": "count", "SALE_PRICE": "sum"})
totals = totals.reset_index().rename( columns = {"COLUMN_NUMBER": "Volume", "SALE_PRICE": "Total", "COUNTY": "County"})

# %%
totals.sort_values(by=["Total"])
# Out:
#        County  Volume         Total
# 13   Longford    4091  4.019421e+08
# 11    Leitrim    4334  4.396845e+08
# 17   Monaghan    3720  4.885930e+08
# 19  Roscommon    6825  7.125493e+08
# 0      Carlow    5194  7.945539e+08
# 18     Offaly    5726  7.955191e+08
# 1       Cavan    7376  8.768370e+08
# 20      Sligo    7065  9.509956e+08
# 10      Laois    7274  1.099404e+09
# 9    Kilkenny    7497  1.368242e+09
# 23  Westmeath    9220  1.413766e+09
# 15       Mayo   11353  1.450426e+09
# 4     Donegal   13126  1.544993e+09
# 2       Clare   10897  1.736318e+09
# 21  Tipperary   12807  1.779597e+09
# 22  Waterford   12644  2.003336e+09
# 7       Kerry   13793  2.219599e+09
# 14      Louth   12680  2.340387e+09
# 24    Wexford   16267  2.610219e+09
# 12   Limerick   17807  3.025799e+09
# 16      Meath   19073  4.595387e+09
# 25    Wicklow   14925  4.677754e+09
# 6      Galway   24009  4.921734e+09
# 8     Kildare   23985  6.401768e+09
# 3        Cork   52200  1.191965e+10
# ...

# %%
dublin = data_frame[data_frame["COUNTY"] == "Dublin"]

# %%
dublin
# Out:
#          SALE_DATE                                        ADDRESS POSTAL_CODE  \
# 0       2010-01-01         5 Braemor Drive, Churchtown, Co.Dublin         NaN
# 2       2010-01-04            1 Meadow Avenue, Dundrum, Dublin 14         NaN
# 5       2010-01-04                 12 Sallymount Avenue, Ranelagh         NaN
# 11      2010-01-04      206 Philipsburgh Avenue, Marino, Dublin 3         NaN
# 12      2010-01-04         22 Laverna Way, Castleknock, Dublin 15         NaN
# ...            ...                                            ...         ...
# 476707  2021-05-28      116A CHERRYWOOD DR, CLONDALKIN, DUBLIN 22   Dublin 22
# 476713  2021-05-28         189 CROSBIES YARD, OSSORY RD, DUBLIN 1    Dublin 1
# 476720  2021-05-28     28 CORDUFF GARDENS, BLANCHARDSTOWN, DUBLIN   Dublin 15
# 476726  2021-05-28  35 The Turnstone, Barnageeragh Cove, Skerries         NaN
# 476731  2021-05-28                69B ORWELL PARK RISE, DUBLIN 6W         NaN
#
# ...

# %%
dublin.loc[dublin["POSTAL_CODE"].isna(), "POSTAL_CODE"] = "Others"

dublin
# Out:
#          SALE_DATE                                        ADDRESS POSTAL_CODE  \
# 0       2010-01-01         5 Braemor Drive, Churchtown, Co.Dublin      Others
# 2       2010-01-04            1 Meadow Avenue, Dundrum, Dublin 14      Others
# 5       2010-01-04                 12 Sallymount Avenue, Ranelagh      Others
# 11      2010-01-04      206 Philipsburgh Avenue, Marino, Dublin 3      Others
# 12      2010-01-04         22 Laverna Way, Castleknock, Dublin 15      Others
# ...            ...                                            ...         ...
# 476707  2021-05-28      116A CHERRYWOOD DR, CLONDALKIN, DUBLIN 22   Dublin 22
# 476713  2021-05-28         189 CROSBIES YARD, OSSORY RD, DUBLIN 1    Dublin 1
# 476720  2021-05-28     28 CORDUFF GARDENS, BLANCHARDSTOWN, DUBLIN   Dublin 15
# 476726  2021-05-28  35 The Turnstone, Barnageeragh Cove, Skerries      Others
# 476731  2021-05-28                69B ORWELL PARK RISE, DUBLIN 6W      Others
#
# ...

# %%
dublin.groupby("POSTAL_CODE").agg({"COLUMN_NUMBER": "count", "SALE_PRICE": "sum"}).reset_index().sort_values(by=["SALE_PRICE"])
# Out:
#              POSTAL_CODE  COLUMN_NUMBER    SALE_PRICE
# 0   Baile ?tha Cliath 17              1  1.150450e+05
# 2   Baile �tha Cliath 15              1  2.500000e+05
# 6    Baile �tha Cliath 5              1  2.500000e+05
# 1   Baile �tha Cliath 14              1  2.720000e+05
# 7    Baile �tha Cliath 9              1  3.420000e+05
# 30          N� Bhaineann              1  3.750000e+05
# 5    Baile �tha Cliath 4              1  5.318670e+05
# 4    Baile �tha Cliath 3              2  6.380000e+05
# 3   Baile �tha Cliath 18              2  8.800000e+05
# 9              Dublin 10           1221  2.028378e+08
# 16             Dublin 17           1017  2.450808e+08
# 26             Dublin 6w            760  3.798778e+08
# 19             Dublin 20           1076  4.210938e+08
# 20             Dublin 22           2688  6.566278e+08
# 18              Dublin 2           1742  9.183753e+08
# 24              Dublin 5           3491  1.209988e+09
# ...

# %%
"116A CHERRYWOOD DR, CLONDALKIN, DUBLIN 22".split(',')[-1].lower().strip().split(' ')[-1]
# Out:
# '22'

# %%
"116A CHERRYWOOD DR, CLONDALKIN, DUBLIN 22".split(' ')[-1]
# Out:
# '22'

# %%
test = [1, 2, 3, 4, 5, 6, 7]
test[-3:]
# Out:
# [5, 6, 7]

# %%
"116A CHERRYWOOD DR, CLONDALKIN, DUBLIN 22".split(' ')[3]
# Out:
# 'CLONDALKIN,'

# %%
"Hello class"[-3]
# Out:
# 'a'
