# %% [markdown]
# # Exploring Population Trends in Ireland ☘️
# ***

# %% [markdown]
# ### Name: Stephen Hasson
# ### Student No: sba23014
# ### Student Email: sba23014@student.cct.ie
# ### Course: CCT MSC in Data Analytics
# ### Assignment: MSC_DA_CA1
# ### Year: Sept-23 Intake
# ### Data Source: https://data.cso.ie/product/pme
# ***

# %% [markdown]
# ## Table of Contents
#
# ### 1. [Data Cleaning](#Data-Cleaning)
# ### 2. [Data Cleaning](#Data-Cleaning)
# ### 3. [Data Cleaning](#Data-Cleaning)
# ### 4. [Data Cleaning](#Data-Cleaning)
# ### 5. [Data Cleaning](#Data-Cleaning)
# ### 6. [Data Cleaning](#Data-Cleaning)
# ### 7. [Data Cleaning](#Data-Cleaning)
# ### 8. [Data Cleaning](#Data-Cleaning)
# ### 9. [Data Cleaning](#Data-Cleaning)
# ### 10. [Data Cleaning](#Data-Cleaning)
# ***

# %% [markdown]
# ## 1. Import packages & load data

# %%
# Import eda & visualisation packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Import machine learning packages from sklearn
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score

# Configure default colour scheme for seaborn
sns.set(color_codes=True)

# Display all columns of the pandas df
pd.set_option('display.max_columns', None)

# %%
# Specify the url of the 'xxx' dataset, saved in github account
pop_change_url = 'https://raw.githubusercontent.com/sba23014/cct_msc_data_analytics/main/s1_ca1/datasets/20230925_annual_population_change_1951_to_2023.csv'
pop_est_url = 'https://raw.githubusercontent.com/sba23014/cct_msc_data_analytics/main/s1_ca1/datasets/20230925_population_estimates_1950_to_2023.csv'
gdp_gnp_url = 'https://raw.githubusercontent.com/sba23014/cct_msc_data_analytics/main/s1_ca1/datasets/20230901_gdp_%26_gnp_1995_to_2023.csv'

# Read files from the github url's into the pandas DataFrame (df)
pop_change_df = pd.read_csv(pop_change_url)
pop_est_df = pd.read_csv(pop_est_url)
gdp_gnp_df = pd.read_csv(gdp_gnp_url)

# %%
# Return the first 5 rows to validate df creation
pop_change_df.head()
# Out:
#   STATISTIC           STATISTIC Label  TLIST(A1)  Year  C02541V03076  \
# 0     PEA15  Annual Population Change       1951  1951             1
# 1     PEA15  Annual Population Change       1951  1951             2
# 2     PEA15  Annual Population Change       1951  1951             3
# 3     PEA15  Annual Population Change       1951  1951             4
# 4     PEA15  Annual Population Change       1951  1951             5
#
#           Component      UNIT  VALUE
# 0     Annual births  Thousand    NaN
# 1     Annual deaths  Thousand    NaN
# 2  Natural increase  Thousand   26.6
# 3        Immigrants  Thousand    NaN
# 4         Emigrants  Thousand    NaN

# %%
# Return the first 5 rows to validate df creation
pop_est_df.head()
# Out:
#   STATISTIC                          STATISTIC Label  TLIST(A1)  Year  \
# 0     PEA01  Population Estimates (Persons in April)       1950  1950
# 1     PEA01  Population Estimates (Persons in April)       1950  1950
# 2     PEA01  Population Estimates (Persons in April)       1950  1950
# 3     PEA01  Population Estimates (Persons in April)       1950  1950
# 4     PEA01  Population Estimates (Persons in April)       1950  1950
#
#   C02076V02508     Age Group C02199V02655         Sex      UNIT  VALUE
# 0          200  Under 1 year            -  Both sexes  Thousand   61.1
# 1          200  Under 1 year            1        Male  Thousand   31.4
# 2          200  Under 1 year            2      Female  Thousand   29.7
# 3          205   0 - 4 years            -  Both sexes  Thousand    NaN
# 4          205   0 - 4 years            1        Male  Thousand    NaN

# %%
# Return the first 5 rows to validate df creation
gdp_gnp_df.head()
# Out:
#   STATISTIC               Statistic Label  TLIST(Q1) Quarter C02196V02652  \
# 0  NAQ03C01  GVA at Constant Basic Prices      19951  1995Q1            -
# 1  NAQ03C01  GVA at Constant Basic Prices      19952  1995Q2            -
# 2  NAQ03C01  GVA at Constant Basic Prices      19953  1995Q3            -
# 3  NAQ03C01  GVA at Constant Basic Prices      19954  1995Q4            -
# 4  NAQ03C01  GVA at Constant Basic Prices      19961  1996Q1            -
#
#    State          UNIT  VALUE
# 0  State  Euro Million  21283
# 1  State  Euro Million  22083
# 2  State  Euro Million  22529
# 3  State  Euro Million  22342
# 4  State  Euro Million  22989

# %% [markdown]
# ## 2. Initial data exploration & cleaning

# %% [markdown]
# ## Exploring population '20230925_annual_population_change_1951_to_2023' dataset first

# %%
# Print the dimensionality of the df
pop_change_df.shape
# Out:
# (584, 8)

# %% [markdown]
# 584 rows & 8 columns

# %%
# Return the first 15 rows to validate df creation
pop_change_df.head(15)
# Out:
#    STATISTIC           STATISTIC Label  TLIST(A1)  Year  C02541V03076  \
# 0      PEA15  Annual Population Change       1951  1951             1
# 1      PEA15  Annual Population Change       1951  1951             2
# 2      PEA15  Annual Population Change       1951  1951             3
# 3      PEA15  Annual Population Change       1951  1951             4
# 4      PEA15  Annual Population Change       1951  1951             5
# 5      PEA15  Annual Population Change       1951  1951             6
# 6      PEA15  Annual Population Change       1951  1951             7
# 7      PEA15  Annual Population Change       1951  1951             8
# 8      PEA15  Annual Population Change       1952  1952             1
# 9      PEA15  Annual Population Change       1952  1952             2
# 10     PEA15  Annual Population Change       1952  1952             3
# 11     PEA15  Annual Population Change       1952  1952             4
# 12     PEA15  Annual Population Change       1952  1952             5
# 13     PEA15  Annual Population Change       1952  1952             6
# 14     PEA15  Annual Population Change       1952  1952             7
#
#             Component      UNIT   VALUE
# 0       Annual births  Thousand     NaN
# 1       Annual deaths  Thousand     NaN
# 2    Natural increase  Thousand    26.6
# 3          Immigrants  Thousand     NaN
# 4           Emigrants  Thousand     NaN
# 5       Net migration  Thousand   -35.0
# 6   Population change  Thousand    -8.4
# 7          Population  Thousand  2960.6
# 8       Annual births  Thousand     NaN
# 9       Annual deaths  Thousand     NaN
# 10   Natural increase  Thousand    27.3
# 11         Immigrants  Thousand     NaN
# 12          Emigrants  Thousand     NaN
# 13      Net migration  Thousand   -35.0
# 14  Population change  Thousand    -7.7

# %% [markdown]
# Notes:
# * Value column contains nulls
# * There are several different unique 'Components', for meaningful results splitting this data will be essential
# * Numerous 'system code' type columns: 'STATISTIC', 'TLIST(A1)', 'C02541V03076'
# * Validate mapping of 'system code' type columns: 'STATISTIC', 'TLIST(A1)', 'C02541V03076' against labels, if 1:1 then drop as required
# * 'C02541V03076' already in numeric datatype format, could be kept for ML purposes
# * 'UNIT' column specifies the denomination of 'Value' column, this could be transformed to the correct value
# * Based on date range in question several observations can be removed based on 'Year'
# * Identifying what to do with 'Value' NaNs important

# %%
# Print a concise summary of the df
pop_change_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATISTIC        584 non-null    object
#  1   STATISTIC Label  584 non-null    object
#  2   TLIST(A1)        584 non-null    int64
#  3   Year             584 non-null    int64
#  4   C02541V03076     584 non-null    int64
#  5   Component        584 non-null    object
#  6   UNIT             584 non-null    object
#  7   VALUE            440 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 36.6+ KB

# %%
# Generate descriptive statistics for all attributes
pop_change_df.describe(include = 'all')
# Out:
#        STATISTIC           STATISTIC Label    TLIST(A1)         Year  \
# count        584                       584   584.000000   584.000000
# unique         1                         1          NaN          NaN
# top        PEA15  Annual Population Change          NaN          NaN
# freq         584                       584          NaN          NaN
# mean         NaN                       NaN  1987.000000  1987.000000
# std          NaN                       NaN    21.089371    21.089371
# min          NaN                       NaN  1951.000000  1951.000000
# 25%          NaN                       NaN  1969.000000  1969.000000
# 50%          NaN                       NaN  1987.000000  1987.000000
# 75%          NaN                       NaN  2005.000000  2005.000000
# max          NaN                       NaN  2023.000000  2023.000000
#
#         C02541V03076      Component      UNIT        VALUE
# count     584.000000            584       584   440.000000
# unique           NaN              8         1          NaN
# top              NaN  Annual births  Thousand          NaN
# freq             NaN             73       584          NaN
# mean        4.500000            NaN       NaN   633.262273
# std         2.293252            NaN       NaN  1378.671718
# min         1.000000            NaN       NaN   -58.000000
# 25%         2.750000            NaN       NaN    24.775000
# 50%         4.500000            NaN       NaN    35.550000
# 75%         6.250000            NaN       NaN    70.775000
# max         8.000000            NaN       NaN  5281.600000

# %% [markdown]
# * Value column contains nulls
# * Several rows are objects and don't have descriptive statistics
# * Remaining columns all appear to have no missing values

# %% [markdown]
# * Check and remove duplicates

# %%
# Total number of rows and columns
print('pop_change_df shape:')
print(pop_change_df.shape)
print()

# Rows containing duplicate data
pop_change_dup_rows_df = pop_change_df[pop_change_df.duplicated()]
print('Number of duplicate rows:')
print(pop_change_dup_rows_df.shape)
print()

# Used to count the number of rows before removing the data
print('Row count before removing duplicates:')
print()
print(pop_change_df.count())
print()

# Dropping the duplicates
pop_change_df = pop_change_df.drop_duplicates()

# Counting the number of rows after removing duplicates.
print('Row count after removing duplicates:')
print()
print(pop_change_df.count())
print()
# Out:
# pop_change_df shape:
# (584, 8)
#
# Number of duplicate rows:
# (0, 8)
#
# Row count before removing duplicates:
#
# STATISTIC          584
# STATISTIC Label    584
# TLIST(A1)          584
# Year               584
# C02541V03076       584
# Component          584
# UNIT               584
# VALUE              440
# dtype: int64
#
# Row count after removing duplicates:
#
# STATISTIC          584
# STATISTIC Label    584
# TLIST(A1)          584
# Year               584
# C02541V03076       584
# Component          584
# UNIT               584
# VALUE              440
# dtype: int64

# %% [markdown]
# * Numerous 'system code' type columns: 'STATISTIC', 'TLIST(A1)', 'C02541V03076'
# * Validate that they are indeed 1:1 mapping, if so can drop additional columns

# %%
def verify_one_to_one_mapping(df, column1, column2):
    """
    Verifies if each unique value in column1 maps to a single unique value in column2.
    
    Parameters:
        df (DataFrame): The DataFrame containing the columns to be checked.
        column1 (str): The name of the first column.
        column2 (str): The name of the second column.
        
    Returns:
        bool: True if it's a 1:1 mapping, False otherwise.
    """
    
    # Group the DataFrame by column1 and get unique values in column2 for each group
    grouped = df.groupby(column1)[column2].unique().reset_index()
    
    # Check if each unique value in column1 maps to a single unique value in column2
    is_one_to_one = all(grouped[column2].apply(len) == 1)
    
    return is_one_to_one

# %%
# run code

statistic_mapping = verify_one_to_one_mapping(pop_change_df, 'STATISTIC', 'STATISTIC Label')
year_mapping = verify_one_to_one_mapping(pop_change_df, 'TLIST(A1)', 'Year')
component_mapping = verify_one_to_one_mapping(pop_change_df, 'C02541V03076', 'Component')

print('"STATISTIC" & "STATISTIC Label" mapping one-to-one:', statistic_mapping)
print('"TLIST(A1)" & "Year" mapping one-to-one:', year_mapping)
print('"C02541V03076" & "Component" mapping one-to-one:', component_mapping)
# Out:
# "STATISTIC" & "STATISTIC Label" mapping one-to-one: True
# "TLIST(A1)" & "Year" mapping one-to-one: True
# "C02541V03076" & "Component" mapping one-to-one: True

# %%
# Validate only one denomination value in the 'UNIT' column
pop_change_df['UNIT'].unique()
# Out:
# array(['Thousand'], dtype=object)

# %% [markdown]
# * It's fine to drop those additional columns as they are not serving the dataset

# %%
# we don't these columns
pop_change_df.drop(['STATISTIC', 'STATISTIC Label', 'TLIST(A1)', 'C02541V03076', 'UNIT'], axis = 1, inplace = True)

pop_change_df
# Out:
#      Year          Component   VALUE
# 0    1951      Annual births     NaN
# 1    1951      Annual deaths     NaN
# 2    1951   Natural increase    26.6
# 3    1951         Immigrants     NaN
# 4    1951          Emigrants     NaN
# ..    ...                ...     ...
# 579  2023         Immigrants   141.6
# 580  2023          Emigrants    64.0
# 581  2023      Net migration    77.6
# 582  2023  Population change    97.6
# 583  2023         Population  5281.6
#
# [584 rows x 3 columns]

# %% [markdown]
# * Renaming columns

# %%
# Rename columns
pop_change_df.rename(columns = {'VALUE': 'Value (K)'}, inplace = True)

# Validate changes
pop_change_df.head()
# Out:
#    Year         Component  Value (K)
# 0  1951     Annual births        NaN
# 1  1951     Annual deaths        NaN
# 2  1951  Natural increase       26.6
# 3  1951        Immigrants        NaN
# 4  1951         Emigrants        NaN

# %% [markdown]
# * Create an additional column for the 'Value (K)' in the raw format

# %%
pop_change_df['Value'] = pop_change_df['Value (K)'] * 1000

pop_change_df
# Out:
#      Year          Component  Value (K)      Value
# 0    1951      Annual births        NaN        NaN
# 1    1951      Annual deaths        NaN        NaN
# 2    1951   Natural increase       26.6    26600.0
# 3    1951         Immigrants        NaN        NaN
# 4    1951          Emigrants        NaN        NaN
# ..    ...                ...        ...        ...
# 579  2023         Immigrants      141.6   141600.0
# 580  2023          Emigrants       64.0    64000.0
# 581  2023      Net migration       77.6    77600.0
# 582  2023  Population change       97.6    97600.0
# 583  2023         Population     5281.6  5281600.0
#
# [584 rows x 4 columns]

# %%
# we don't need the 'Value (K)' column anymore
pop_change_df.drop(['Value (K)'], axis = 1, inplace = True)

pop_change_df
# Out:
#      Year          Component      Value
# 0    1951      Annual births        NaN
# 1    1951      Annual deaths        NaN
# 2    1951   Natural increase    26600.0
# 3    1951         Immigrants        NaN
# 4    1951          Emigrants        NaN
# ..    ...                ...        ...
# 579  2023         Immigrants   141600.0
# 580  2023          Emigrants    64000.0
# 581  2023      Net migration    77600.0
# 582  2023  Population change    97600.0
# 583  2023         Population  5281600.0
#
# [584 rows x 3 columns]

# %%
# Validate unique component values
pop_change_df['Component'].unique()
# Out:
# array(['Annual births', 'Annual deaths', 'Natural increase', 'Immigrants',
#        'Emigrants', 'Net migration', 'Population change', 'Population'],
#       dtype=object)

# %% [markdown]
# * There are several components within the dataset, some of them measuring individual statistics and some which are calculated values e.g.
#     * Natural increase = Annual births - Annual deaths
#     * Net migration = Immigrants - Emigrants
#     * Population change = Population - Population (previous year)
# * Need to pivot the dataset so that there's only a single row per year, the component values are moved to columns

# %%
# Pivot the DataFrame so that unique 'Component' values become columns
pop_change_pivot_df = pop_change_df.pivot(index = 'Year', columns = 'Component', values = 'Value')

pop_change_pivot_df.head()
# Out:
# Component  Annual births  Annual deaths  Emigrants  Immigrants  \
# Year
# 1951                 NaN            NaN        NaN         NaN
# 1952                 NaN            NaN        NaN         NaN
# 1953                 NaN            NaN        NaN         NaN
# 1954                 NaN            NaN        NaN         NaN
# 1955                 NaN            NaN        NaN         NaN
#
# Component  Natural increase  Net migration  Population  Population change
# Year
# 1951                26600.0       -35000.0   2960600.0            -8400.0
# 1952                27300.0       -35000.0   2952900.0            -7700.0
# 1953                29100.0       -33000.0   2949000.0            -3900.0
# 1954                28200.0       -36000.0   2941200.0            -7800.0
# 1955                24700.0       -45000.0   2920900.0           -20300.0

# %% [markdown]
# * Null values will be investigated once the data is joined

# %% [markdown]
# * Only care about the last 25 full years
# * Drop any observations outside of range: >= 1998 AND <= 2022

# %%
pop_change_pivot_df = pop_change_pivot_df.loc[1998:2022]

pop_change_pivot_df
# Out:
# Component  Annual births  Annual deaths  Emigrants  Immigrants  \
# Year
# 1998             52700.0        31200.0    28600.0     46000.0
# 1999             53700.0        32400.0    31500.0     48900.0
# 2000             54000.0        32100.0    26600.0     52600.0
# 2001             55100.0        30200.0    26200.0     59000.0
# 2002             58100.0        29300.0    25600.0     66900.0
# 2003             60800.0        28900.0    29300.0     60000.0
# 2004             62000.0        28600.0    26500.0     58500.0
# 2005             61400.0        27900.0    29400.0     84600.0
# 2006             61200.0        27000.0    36000.0    107800.0
# 2007             66600.0        28400.0    46300.0    151100.0
# 2008             73000.0        28000.0    49200.0    113500.0
# 2009             75300.0        28600.0    72000.0     73700.0
# 2010             77200.0        28400.0    69200.0     41800.0
# 2011             75100.0        27700.0    80600.0     53300.0
# 2012             73200.0        28700.0    83000.0     57300.0
# 2013             69400.0        29800.0    81300.0     62700.0
# 2014             68400.0        29200.0    75000.0     66500.0
# 2015             66400.0        29900.0    70000.0     75900.0
# 2016             65400.0        29800.0    66200.0     82300.0
# 2017             63400.0        31300.0    56100.0     95300.0
# 2018             61600.0        32000.0    51600.0     96000.0
# 2019             60500.0        30900.0    53100.0     97100.0
# 2020             59100.0        32400.0    50900.0     95600.0
# 2021             57300.0        34300.0    52300.0     74100.0
# 2022             59700.0        33600.0    56100.0    107800.0
#
# Component  Natural increase  Net migration  Population  Population change
# Year
# 1998                21500.0        17400.0   3703100.0            38800.0
# 1999                21200.0        17300.0   3741600.0            38500.0
# 2000                21800.0        26000.0   3789500.0            47900.0
# 2001                24800.0        32800.0   3847200.0            57700.0
# 2002                28800.0        41300.0   3917200.0            70000.0
# 2003                31900.0        30700.0   3979900.0            62600.0
# 2004                33300.0        32000.0   4045200.0            65300.0
# 2005                33500.0        55100.0   4133800.0            88600.0
# 2006                34200.0        71800.0   4232900.0           106000.0
# 2007                38200.0       104800.0   4375800.0           142900.0
# 2008                44900.0        64300.0   4485100.0           109200.0
# 2009                46700.0         1600.0   4533400.0            48300.0
# 2010                48800.0       -27500.0   4554800.0            21400.0
# 2011                47500.0       -27400.0   4574900.0            20100.0
# 2012                44500.0       -25700.0   4593700.0            18800.0
# 2013                39600.0       -18700.0   4614700.0            21000.0
# 2014                39200.0        -8500.0   4645400.0            30800.0
# 2015                36500.0         5900.0   4687800.0            42300.0
# 2016                35600.0        16200.0   4739600.0            51800.0
# 2017                32100.0        39200.0   4810900.0            71300.0
# 2018                29600.0        44400.0   4884900.0            74000.0
# 2019                29600.0        44000.0   4958500.0            73600.0
# 2020                26700.0        44700.0   5029900.0            71400.0
# 2021                23000.0        21800.0   5074700.0            44800.0
# 2022                26100.0        51700.0   5184000.0            77800.0

# %%
# Count the number of observations (rows), ensure that it's 25
num_observations = len(pop_change_pivot_df)

num_observations
# Out:
# 25

# %%
# Setting the index to 'Year'
pop_change_df.set_index('Year', inplace = True)

# %% [markdown]
# ### Exploring population 20230925_population_estimates_1950_to_2023' dataset second

# %%
# Print the dimensionality of the df
pop_est_df.shape
# Out:
# (5994, 10)

# %%
# Return the first 15 rows to validate df creation
pop_est_df.head(15)
# Out:
#    STATISTIC                          STATISTIC Label  TLIST(A1)  Year  \
# 0      PEA01  Population Estimates (Persons in April)       1950  1950
# 1      PEA01  Population Estimates (Persons in April)       1950  1950
# 2      PEA01  Population Estimates (Persons in April)       1950  1950
# 3      PEA01  Population Estimates (Persons in April)       1950  1950
# 4      PEA01  Population Estimates (Persons in April)       1950  1950
# 5      PEA01  Population Estimates (Persons in April)       1950  1950
# 6      PEA01  Population Estimates (Persons in April)       1950  1950
# 7      PEA01  Population Estimates (Persons in April)       1950  1950
# 8      PEA01  Population Estimates (Persons in April)       1950  1950
# 9      PEA01  Population Estimates (Persons in April)       1950  1950
# 10     PEA01  Population Estimates (Persons in April)       1950  1950
# 11     PEA01  Population Estimates (Persons in April)       1950  1950
# 12     PEA01  Population Estimates (Persons in April)       1950  1950
# 13     PEA01  Population Estimates (Persons in April)       1950  1950
# 14     PEA01  Population Estimates (Persons in April)       1950  1950
#
#    C02076V02508     Age Group C02199V02655         Sex      UNIT  VALUE
# 0           200  Under 1 year            -  Both sexes  Thousand   61.1
# 1           200  Under 1 year            1        Male  Thousand   31.4
# 2           200  Under 1 year            2      Female  Thousand   29.7
# 3           205   0 - 4 years            -  Both sexes  Thousand    NaN
# 4           205   0 - 4 years            1        Male  Thousand    NaN
# 5           205   0 - 4 years            2      Female  Thousand    NaN
# 6           215  0 - 14 years            -  Both sexes  Thousand  851.2
# 7           215  0 - 14 years            1        Male  Thousand  434.6
# 8           215  0 - 14 years            2      Female  Thousand  416.6
# 9           225   1 - 4 years            -  Both sexes  Thousand  249.1
# 10          225   1 - 4 years            1        Male  Thousand  127.5
# 11          225   1 - 4 years            2      Female  Thousand  121.6
# 12          245   5 - 9 years            -  Both sexes  Thousand  278.9
# 13          245   5 - 9 years            1        Male  Thousand  142.3
# 14          245   5 - 9 years            2      Female  Thousand  136.6

# %% [markdown]
# Notes:
# * Value column contains nulls
# * There are several different unique 'Sex' values, for meaningful results splitting this data will be essential
# * Numerous 'system code' type columns: 'STATISTIC', 'TLIST(A1)', 'C02076V02508', 'C02199V02655'
# * Validate mapping of 'system code' type columns: 'STATISTIC', 'TLIST(A1)', 'C02076V02508', 'C02199V02655' against labels, if 1:1 then drop as required
# * 'UNIT' column specifies the denomination of 'Value' column, this could be transformed to the correct value
# * Based on date range in question several observations can be removed based on 'Year'
# * Identifying what to do with 'Value' NaNs important

# %%
# Print a concise summary of the df
pop_est_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5994 entries, 0 to 5993
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATISTIC        5994 non-null   object
#  1   STATISTIC Label  5994 non-null   object
#  2   TLIST(A1)        5994 non-null   int64
#  3   Year             5994 non-null   int64
#  4   C02076V02508     5994 non-null   object
#  5   Age Group        5994 non-null   object
#  6   C02199V02655     5994 non-null   object
#  7   Sex              5994 non-null   object
#  8   UNIT             5994 non-null   object
#  9   VALUE            5880 non-null   float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 468.4+ KB

# %%
# Generate descriptive statistics for all attributes
pop_est_df.describe(include = 'all')
# Out:
#        STATISTIC                          STATISTIC Label    TLIST(A1)  \
# count       5994                                     5994  5994.000000
# unique         1                                        1          NaN
# top        PEA01  Population Estimates (Persons in April)          NaN
# freq        5994                                     5994          NaN
# mean         NaN                                      NaN  1986.500000
# std          NaN                                      NaN    21.361791
# min          NaN                                      NaN  1950.000000
# 25%          NaN                                      NaN  1968.000000
# 50%          NaN                                      NaN  1986.500000
# 75%          NaN                                      NaN  2005.000000
# max          NaN                                      NaN  2023.000000
#
#                Year C02076V02508     Age Group C02199V02655         Sex  \
# count   5994.000000         5994          5994         5994        5994
# unique          NaN           27            27            3           3
# top             NaN          200  Under 1 year            -  Both sexes
# freq            NaN          222           222         1998        1998
# mean    1986.500000          NaN           NaN          NaN         NaN
# std       21.361791          NaN           NaN          NaN         NaN
# min     1950.000000          NaN           NaN          NaN         NaN
# 25%     1968.000000          NaN           NaN          NaN         NaN
# 50%     1986.500000          NaN           NaN          NaN         NaN
# 75%     2005.000000          NaN           NaN          NaN         NaN
# max     2023.000000          NaN           NaN          NaN         NaN
#
#             UNIT        VALUE
# count       5994  5880.000000
# unique         1          NaN
# top     Thousand          NaN
# freq        5994          NaN
# mean         NaN   347.001088
# std          NaN   601.822682
# min          NaN     5.500000
# 25%          NaN    79.475000
# 50%          NaN   151.700000
# 75%          NaN   307.725000
# max          NaN  5281.600000

# %% [markdown]
# * Value column contains nulls / missing values
# * Several rows are objects and don't have descriptive statistics
# * Remaining columns all appear to have no missing values

# %% [markdown]
# * Numerous 'system code' type columns: 'STATISTIC', 'TLIST(A1)', 'C02541V03076'
# * Validate that they are indeed 1:1 mapping, if so can drop additional columns

# %%
# run code

statistic_mapping = verify_one_to_one_mapping(pop_est_df, 'STATISTIC', 'STATISTIC Label')
year_mapping = verify_one_to_one_mapping(pop_est_df, 'TLIST(A1)', 'Year')
component_mapping = verify_one_to_one_mapping(pop_est_df, 'C02076V02508', 'Age Group')
sex_mapping = verify_one_to_one_mapping(pop_est_df, 'C02199V02655', 'Sex')

print('"STATISTIC" & "STATISTIC Label" mapping one-to-one:', statistic_mapping)
print('"TLIST(A1)" & "Year" mapping one-to-one:', year_mapping)
print('"C02541V03076" & "Component" mapping one-to-one:', component_mapping)
print('"C02199V02655" & "Sex" mapping one-to-one:', sex_mapping)
# Out:
# "STATISTIC" & "STATISTIC Label" mapping one-to-one: True
# "TLIST(A1)" & "Year" mapping one-to-one: True
# "C02541V03076" & "Component" mapping one-to-one: True
# "C02199V02655" & "Sex" mapping one-to-one: True

# %% [markdown]
# * Age group is not a variable I want investigate so I will filter the dataset to only include 'all ages'

# %%
# Filter the DataFrame to include only rows where 'Age Group' is 'All Ages'
pop_est_df = pop_est_df[pop_est_df['Age Group'] == 'All ages']

pop_est_df
# Out:
#      STATISTIC                          STATISTIC Label  TLIST(A1)  Year  \
# 78       PEA01  Population Estimates (Persons in April)       1950  1950
# 79       PEA01  Population Estimates (Persons in April)       1950  1950
# 80       PEA01  Population Estimates (Persons in April)       1950  1950
# 159      PEA01  Population Estimates (Persons in April)       1951  1951
# 160      PEA01  Population Estimates (Persons in April)       1951  1951
# ...        ...                                      ...        ...   ...
# 5911     PEA01  Population Estimates (Persons in April)       2022  2022
# 5912     PEA01  Population Estimates (Persons in April)       2022  2022
# 5991     PEA01  Population Estimates (Persons in April)       2023  2023
# 5992     PEA01  Population Estimates (Persons in April)       2023  2023
# 5993     PEA01  Population Estimates (Persons in April)       2023  2023
#
#      C02076V02508 Age Group C02199V02655         Sex      UNIT   VALUE
# 78              -  All ages            -  Both sexes  Thousand  2969.0
# 79              -  All ages            1        Male  Thousand  1510.0
# 80              -  All ages            2      Female  Thousand  1459.0
# 159             -  All ages            -  Both sexes  Thousand  2960.6
# 160             -  All ages            1        Male  Thousand  1506.6
# ...           ...       ...          ...         ...       ...     ...
# 5911            -  All ages            1        Male  Thousand  2562.0
# 5912            -  All ages            2      Female  Thousand  2622.0
# 5991            -  All ages            -  Both sexes  Thousand  5281.6
# 5992            -  All ages            1        Male  Thousand  2606.2
# 5993            -  All ages            2      Female  Thousand  2675.4
#
# [222 rows x 10 columns]

# %%
# Validate only one denomination value in the 'UNIT' column
pop_est_df['UNIT'].unique()
# Out:
# array(['Thousand'], dtype=object)

# %% [markdown]
# * It's fine to drop those additional columns as they are not serving the dataset now that I've gotten my subset

# %%
# we don't want these columns
pop_est_df.drop(['STATISTIC', 'STATISTIC Label', 'TLIST(A1)', 'C02076V02508', 'Age Group', 'C02199V02655', 'UNIT'], axis = 1, inplace = True)

pop_est_df
# Out:
#       Year         Sex   VALUE
# 78    1950  Both sexes  2969.0
# 79    1950        Male  1510.0
# 80    1950      Female  1459.0
# 159   1951  Both sexes  2960.6
# 160   1951        Male  1506.6
# ...    ...         ...     ...
# 5911  2022        Male  2562.0
# 5912  2022      Female  2622.0
# 5991  2023  Both sexes  5281.6
# 5992  2023        Male  2606.2
# 5993  2023      Female  2675.4
#
# [222 rows x 3 columns]

# %% [markdown]
# * rename columns

# %%
# Rename columns
pop_est_df.rename(columns = {'VALUE': 'Value (K)'}, inplace = True)

# Validate changes
pop_est_df.head()
# Out:
#      Year         Sex  Value (K)
# 78   1950  Both sexes     2969.0
# 79   1950        Male     1510.0
# 80   1950      Female     1459.0
# 159  1951  Both sexes     2960.6
# 160  1951        Male     1506.6

# %% [markdown]
# * Create an additional column for the 'Value (K)' in the raw format

# %%
pop_est_df['Value'] = pop_est_df['Value (K)'] * 1000

pop_est_df
# Out:
#       Year         Sex  Value (K)      Value
# 78    1950  Both sexes     2969.0  2969000.0
# 79    1950        Male     1510.0  1510000.0
# 80    1950      Female     1459.0  1459000.0
# 159   1951  Both sexes     2960.6  2960600.0
# 160   1951        Male     1506.6  1506600.0
# ...    ...         ...        ...        ...
# 5911  2022        Male     2562.0  2562000.0
# 5912  2022      Female     2622.0  2622000.0
# 5991  2023  Both sexes     5281.6  5281600.0
# 5992  2023        Male     2606.2  2606200.0
# 5993  2023      Female     2675.4  2675400.0
#
# [222 rows x 4 columns]

# %%
# we don't need the 'Value (K)' column anymore
pop_est_df.drop(['Value (K)'], axis = 1, inplace = True)

pop_est_df
# Out:
#       Year         Sex      Value
# 78    1950  Both sexes  2969000.0
# 79    1950        Male  1510000.0
# 80    1950      Female  1459000.0
# 159   1951  Both sexes  2960600.0
# 160   1951        Male  1506600.0
# ...    ...         ...        ...
# 5911  2022        Male  2562000.0
# 5912  2022      Female  2622000.0
# 5991  2023  Both sexes  5281600.0
# 5992  2023        Male  2606200.0
# 5993  2023      Female  2675400.0
#
# [222 rows x 3 columns]

# %%
# Validate unique component values
pop_est_df['Sex'].unique()
# Out:
# array(['Both sexes', 'Male', 'Female'], dtype=object)

# %% [markdown]
# * Check and remove duplicates
# * Because I removed the 'Age Group' classification columns, I need to remove duplicates values

# %%
# Total number of rows and columns
print('pop_est_df shape:')
print(pop_est_df.shape)
print()

# Rows containing duplicate data
pop_est_dup_rows_df = pop_est_df[pop_est_df.duplicated()]
print('Number of duplicate rows:')
print(pop_est_dup_rows_df.shape)
print()

# Used to count the number of rows before removing the data
print('Row count before removing duplicates:')
print()
print(pop_est_df.count())
print()

# Dropping the duplicates
pop_est_df = pop_est_df.drop_duplicates()

# Counting the number of rows after removing duplicates.
print('Row count after removing duplicates:')
print()
print(pop_est_df.count())
print()
# Out:
# pop_est_df shape:
# (222, 3)
#
# Number of duplicate rows:
# (0, 3)
#
# Row count before removing duplicates:
#
# Year     222
# Sex      222
# Value    222
# dtype: int64
#
# Row count after removing duplicates:
#
# Year     222
# Sex      222
# Value    222
# dtype: int64

# %%
# Pivot the DataFrame so that unique 'Component' values become columns
pop_est_pivot_df = pop_est_df.pivot(index = 'Year', columns = 'Sex', values = 'Value')

pop_est_pivot_df.head()
# Out:
# Sex   Both sexes     Female       Male
# Year
# 1950   2969000.0  1459000.0  1510000.0
# 1951   2960600.0  1454000.0  1506600.0
# 1952   2952900.0  1452000.0  1500900.0
# 1953   2949000.0  1451100.0  1497900.0
# 1954   2941200.0  1448200.0  1493000.0

# %%
pop_est_pivot_df = pop_est_pivot_df.loc[1998:2022]

pop_est_pivot_df
# Out:
# Sex   Both sexes     Female       Male
# Year
# 1998   3703100.0  1864200.0  1838900.0
# 1999   3741600.0  1883000.0  1858600.0
# 2000   3789500.0  1906600.0  1882900.0
# 2001   3847200.0  1934100.0  1913100.0
# 2002   3917200.0  1971000.0  1946200.0
# 2003   3979900.0  2002900.0  1976900.0
# 2004   4045200.0  2033300.0  2011900.0
# 2005   4133800.0  2072000.0  2061800.0
# 2006   4232900.0  2115600.0  2117300.0
# 2007   4375800.0  2184600.0  2191300.0
# 2008   4485100.0  2246500.0  2238600.0
# 2009   4533400.0  2276100.0  2257300.0
# 2010   4554800.0  2292600.0  2262200.0
# 2011   4574900.0  2304400.0  2270500.0
# 2012   4593700.0  2318700.0  2275000.0
# 2013   4614700.0  2328500.0  2286100.0
# 2014   4645400.0  2346400.0  2299000.0
# 2015   4687800.0  2370100.0  2317700.0
# 2016   4739600.0  2393100.0  2346500.0
# 2017   4810900.0  2430100.0  2380800.0
# 2018   4884900.0  2465400.0  2419500.0
# 2019   4958500.0  2502200.0  2456300.0
# 2020   5029900.0  2538100.0  2491800.0
# 2021   5074700.0  2560600.0  2514000.0
# 2022   5184000.0  2622000.0  2562000.0

# %%
# we don't need the 'Both sexes' column anymore
pop_est_pivot_df.drop(['Both sexes'], axis = 1, inplace = True)

pop_est_pivot_df
# Out:
# Sex      Female       Male
# Year
# 1998  1864200.0  1838900.0
# 1999  1883000.0  1858600.0
# 2000  1906600.0  1882900.0
# 2001  1934100.0  1913100.0
# 2002  1971000.0  1946200.0
# 2003  2002900.0  1976900.0
# 2004  2033300.0  2011900.0
# 2005  2072000.0  2061800.0
# 2006  2115600.0  2117300.0
# 2007  2184600.0  2191300.0
# 2008  2246500.0  2238600.0
# 2009  2276100.0  2257300.0
# 2010  2292600.0  2262200.0
# 2011  2304400.0  2270500.0
# 2012  2318700.0  2275000.0
# 2013  2328500.0  2286100.0
# 2014  2346400.0  2299000.0
# 2015  2370100.0  2317700.0
# 2016  2393100.0  2346500.0
# 2017  2430100.0  2380800.0
# 2018  2465400.0  2419500.0
# 2019  2502200.0  2456300.0
# 2020  2538100.0  2491800.0
# 2021  2560600.0  2514000.0
# 2022  2622000.0  2562000.0

# %%
# Setting the index to 'Year'
pop_est_df.set_index('Year', inplace = True)

# %% [markdown]
# ### Exploring population '20230925_gdp_&_gnp_1995_to_2023' dataset third

# %% [markdown]
# * Check and remove duplicates
# * Because I removed the 'Age Group' classification columns, I need to remove duplicates values

# %%
# Print the dimensionality of the df
gdp_gnp_df.shape
# Out:
# (2736, 8)

# %%
# Return the first 15 rows to validate df creation
gdp_gnp_df.head(15)
# Out:
#    STATISTIC               Statistic Label  TLIST(Q1) Quarter C02196V02652  \
# 0   NAQ03C01  GVA at Constant Basic Prices      19951  1995Q1            -
# 1   NAQ03C01  GVA at Constant Basic Prices      19952  1995Q2            -
# 2   NAQ03C01  GVA at Constant Basic Prices      19953  1995Q3            -
# 3   NAQ03C01  GVA at Constant Basic Prices      19954  1995Q4            -
# 4   NAQ03C01  GVA at Constant Basic Prices      19961  1996Q1            -
# 5   NAQ03C01  GVA at Constant Basic Prices      19962  1996Q2            -
# 6   NAQ03C01  GVA at Constant Basic Prices      19963  1996Q3            -
# 7   NAQ03C01  GVA at Constant Basic Prices      19964  1996Q4            -
# 8   NAQ03C01  GVA at Constant Basic Prices      19971  1997Q1            -
# 9   NAQ03C01  GVA at Constant Basic Prices      19972  1997Q2            -
# 10  NAQ03C01  GVA at Constant Basic Prices      19973  1997Q3            -
# 11  NAQ03C01  GVA at Constant Basic Prices      19974  1997Q4            -
# 12  NAQ03C01  GVA at Constant Basic Prices      19981  1998Q1            -
# 13  NAQ03C01  GVA at Constant Basic Prices      19982  1998Q2            -
# 14  NAQ03C01  GVA at Constant Basic Prices      19983  1998Q3            -
#
#     State          UNIT  VALUE
# 0   State  Euro Million  21283
# 1   State  Euro Million  22083
# 2   State  Euro Million  22529
# 3   State  Euro Million  22342
# 4   State  Euro Million  22989
# 5   State  Euro Million  24022
# 6   State  Euro Million  23775
# 7   State  Euro Million  23722
# 8   State  Euro Million  24656
# 9   State  Euro Million  26327
# 10  State  Euro Million  26393
# 11  State  Euro Million  26941
# 12  State  Euro Million  27120
# 13  State  Euro Million  28211
# 14  State  Euro Million  29099

# %% [markdown]
# Notes:
# * Value column contains nulls
# * There are several different unique 'Sex' values, for meaningful results splitting this data will be essential
# * Numerous 'system code' type columns: 'STATISTIC', 'TLIST(Q1)', 'C02196V02652'
# * Validate mapping of 'system code' type columns: 'STATISTIC', 'TLIST(Q1)', 'C02196V02652' against labels, if 1:1 then drop as required
# * 'UNIT' column specifies the denomination of 'Value' column, this could be transformed to the correct value
# * Based on date range in question several observations can be removed based on 'Year'
# * Identifying what to do with 'Value' NaNs important

# %%
# Print a concise summary of the df
gdp_gnp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2736 entries, 0 to 2735
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATISTIC        2736 non-null   object
#  1   Statistic Label  2736 non-null   object
#  2   TLIST(Q1)        2736 non-null   int64
#  3   Quarter          2736 non-null   object
#  4   C02196V02652     2736 non-null   object
#  5   State            2736 non-null   object
#  6   UNIT             2736 non-null   object
#  7   VALUE            2736 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 171.1+ KB

# %%
# Generate descriptive statistics for all attributes
gdp_gnp_df.describe(include = 'all')
# Out:
#        STATISTIC               Statistic Label     TLIST(Q1) Quarter  \
# count       2736                          2736   2736.000000    2736
# unique        24                            24           NaN     114
# top     NAQ03C01  GVA at Constant Basic Prices           NaN  1995Q1
# freq         114                           114           NaN      24
# mean         NaN                           NaN  20090.026316     NaN
# std          NaN                           NaN     82.289981     NaN
# min          NaN                           NaN  19951.000000     NaN
# 25%          NaN                           NaN  20021.000000     NaN
# 50%          NaN                           NaN  20091.500000     NaN
# 75%          NaN                           NaN  20162.000000     NaN
# max          NaN                           NaN  20232.000000     NaN
#
#        C02196V02652  State          UNIT          VALUE
# count          2736   2736          2736    2736.000000
# unique            1      1             1            NaN
# top               -  State  Euro Million            NaN
# freq           2736   2736          2736            NaN
# mean            NaN    NaN           NaN   23922.203216
# std             NaN    NaN           NaN   31933.678885
# min             NaN    NaN           NaN  -41168.000000
# 25%             NaN    NaN           NaN    -334.250000
# 50%             NaN    NaN           NaN   10117.500000
# 75%             NaN    NaN           NaN   43457.000000
# max             NaN    NaN           NaN  134023.000000

# %% [markdown]
# * No missing values so far
# * Several rows are objects and don't have descriptive statistics
# * Remaining columns all appear to have no missing values
# * Numerous 'system code' type columns: 'STATISTIC', 'TLIST(A1)', 'C02541V03076'
# * Validate that they are indeed 1:1 mapping, if so can drop additional columns

# %%
# run code

statistic_mapping = verify_one_to_one_mapping(gdp_gnp_df, 'STATISTIC', 'Statistic Label')
quarter_mapping = verify_one_to_one_mapping(gdp_gnp_df, 'TLIST(Q1)', 'Quarter')
component_mapping = verify_one_to_one_mapping(gdp_gnp_df, 'C02196V02652', 'State')

print('"STATISTIC" & "Statistic Label" mapping one-to-one:', statistic_mapping)
print('"TLIST(Q1)" & "Quarter" mapping one-to-one:', quarter_mapping)
print('"C02196V02652" & "State" mapping one-to-one:', component_mapping)
# Out:
# "STATISTIC" & "Statistic Label" mapping one-to-one: True
# "TLIST(Q1)" & "Quarter" mapping one-to-one: True
# "C02196V02652" & "State" mapping one-to-one: True

# %%
gdp_gnp_df['Year'] = gdp_gnp_df['Quarter'].str[:4]
gdp_gnp_df['Quarter No'] = gdp_gnp_df['Quarter'].str[-1]

gdp_gnp_df.head()
# Out:
#   STATISTIC               Statistic Label  TLIST(Q1) Quarter C02196V02652  \
# 0  NAQ03C01  GVA at Constant Basic Prices      19951  1995Q1            -
# 1  NAQ03C01  GVA at Constant Basic Prices      19952  1995Q2            -
# 2  NAQ03C01  GVA at Constant Basic Prices      19953  1995Q3            -
# 3  NAQ03C01  GVA at Constant Basic Prices      19954  1995Q4            -
# 4  NAQ03C01  GVA at Constant Basic Prices      19961  1996Q1            -
#
#    State          UNIT  VALUE  Year Quarter No
# 0  State  Euro Million  21283  1995          1
# 1  State  Euro Million  22083  1995          2
# 2  State  Euro Million  22529  1995          3
# 3  State  Euro Million  22342  1995          4
# 4  State  Euro Million  22989  1996          1

# %%
# Validate only one denomination value in the 'UNIT' column
gdp_gnp_df['State'].unique()
# Out:
# array(['State'], dtype=object)

# %%
# Validate only one denomination value in the 'UNIT' column
gdp_gnp_df['UNIT'].unique()
# Out:
# array(['Euro Million'], dtype=object)

# %% [markdown]
# * It's fine to drop those additional columns as they are not serving the dataset now that I've gotten my subset

# %%
# we don't want these columns
gdp_gnp_df.drop(['STATISTIC', 'TLIST(Q1)', 'Quarter', 'C02196V02652', 'State', 'UNIT'], axis = 1, inplace = True)

gdp_gnp_df
# Out:
#                                         Statistic Label   VALUE  Year  \
# 0                          GVA at Constant Basic Prices   21283  1995
# 1                          GVA at Constant Basic Prices   22083  1995
# 2                          GVA at Constant Basic Prices   22529  1995
# 3                          GVA at Constant Basic Prices   22342  1995
# 4                          GVA at Constant Basic Prices   22989  1996
# ...                                                 ...     ...   ...
# 2731  GNP at Current Market Prices (Seasonally Adjus...   93287  2022
# 2732  GNP at Current Market Prices (Seasonally Adjus...   89542  2022
# 2733  GNP at Current Market Prices (Seasonally Adjus...   93467  2022
# 2734  GNP at Current Market Prices (Seasonally Adjus...   88873  2023
# 2735  GNP at Current Market Prices (Seasonally Adjus...  102104  2023
#
#      Quarter No
# 0             1
# 1             2
# 2             3
# 3             4
# 4             1
# ...         ...
# 2731          2
# 2732          3
# 2733          4
# 2734          1
# 2735          2
#
# [2736 rows x 4 columns]

# %%
# Check for each 'Statistic Label' & 'Year' grouping to ensure there are 4 'Quarter No' values
grouped = gdp_gnp_df.groupby(['Statistic Label', 'Year'])['Quarter No'].nunique().reset_index()
grouped['Check'] = grouped['Quarter No'] == 4

grouped
# Out:
#                                        Statistic Label  Year  Quarter No  \
# 0                        GDP at Constant Market Prices  1995           4
# 1                        GDP at Constant Market Prices  1996           4
# 2                        GDP at Constant Market Prices  1997           4
# 3                        GDP at Constant Market Prices  1998           4
# 4                        GDP at Constant Market Prices  1999           4
# ..                                                 ...   ...         ...
# 691  Taxes on Products at Current Prices (Seasonall...  2019           4
# 692  Taxes on Products at Current Prices (Seasonall...  2020           4
# 693  Taxes on Products at Current Prices (Seasonall...  2021           4
# 694  Taxes on Products at Current Prices (Seasonall...  2022           4
# 695  Taxes on Products at Current Prices (Seasonall...  2023           2
#
#      Check
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# ..     ...
# 691   True
# 692   True
# 693   True
# 694   True
# 695  False
#
# [696 rows x 4 columns]

# %%
# Filter the 'grouped' dataframe to include only rows where 'Check' is False
filtered_grouped = grouped[grouped['Check'] == False]

filtered_grouped
# Out:
#                                        Statistic Label  Year  Quarter No  \
# 28                       GDP at Constant Market Prices  2023           2
# 57   GDP at Constant Market Prices (Seasonally Adju...  2023           2
# 86                        GDP at Current Market Prices  2023           2
# 115  GDP at Current Market Prices (Seasonally Adjus...  2023           2
# 144                      GNP at Constant Market Prices  2023           2
# 173  GNP at Constant Market Prices (Seasonally Adju...  2023           2
# 202                       GNP at Current Market Prices  2023           2
# 231  GNP at Current Market Prices (Seasonally Adjus...  2023           2
# 260                       GVA at Constant Basic Prices  2023           2
# 289  GVA at Constant Basic Prices (Seasonally Adjus...  2023           2
# 318                        GVA at Current Basic Prices  2023           2
# 347  GVA at Current Basic Prices (Seasonally Adjusted)  2023           2
# 376               Net Factor Income from Rest of World  2023           2
# 405  Net Factor Income from Rest of World (Seasonal...  2023           2
# 434  Net Factor Income from Rest of World at Curren...  2023           2
# 463  Net Factor Income from Rest of World at Curren...  2023           2
# 492                              Subsidies on Products  2023           2
# 521  Subsidies on Products (chain linked annually r...  2023           2
# 550            Subsidies on Products at Current Prices  2023           2
# 579  Subsidies on Products at Current Prices (Seaso...  2023           2
# 608                                  Taxes on Products  2023           2
# 637            Taxes on Products (Seasonally Adjusted)  2023           2
# 666                Taxes on Products at Current Prices  2023           2
# 695  Taxes on Products at Current Prices (Seasonall...  2023           2
#
#      Check
# 28   False
# 57   False
# 86   False
# 115  False
# 144  False
# 173  False
# 202  False
# 231  False
# 260  False
# 289  False
# 318  False
# 347  False
# 376  False
# 405  False
# 434  False
# 463  False
# 492  False
# 521  False
# 550  False
# 579  False
# 608  False
# 637  False
# 666  False
# 695  False

# %% [markdown]
# * Only 2023 hasn't got 4 quarters worth of data, for purpose of analysis I'll only be analysing full years worth of data

# %% [markdown]
# * rename columns

# %%
# Rename columns
gdp_gnp_df.rename(columns = {'VALUE': 'Value (Mn.)'}, inplace = True)

# Validate changes
gdp_gnp_df.head()
# Out:
#                 Statistic Label  Value (Mn.)  Year Quarter No
# 0  GVA at Constant Basic Prices        21283  1995          1
# 1  GVA at Constant Basic Prices        22083  1995          2
# 2  GVA at Constant Basic Prices        22529  1995          3
# 3  GVA at Constant Basic Prices        22342  1995          4
# 4  GVA at Constant Basic Prices        22989  1996          1

# %% [markdown]
# * Create an additional column for the 'Value (K)' in the raw format

# %%
gdp_gnp_df['Value'] = gdp_gnp_df['Value (Mn.)'] * 1000000

gdp_gnp_df
# Out:
#                                         Statistic Label  Value (Mn.)  Year  \
# 0                          GVA at Constant Basic Prices        21283  1995
# 1                          GVA at Constant Basic Prices        22083  1995
# 2                          GVA at Constant Basic Prices        22529  1995
# 3                          GVA at Constant Basic Prices        22342  1995
# 4                          GVA at Constant Basic Prices        22989  1996
# ...                                                 ...          ...   ...
# 2731  GNP at Current Market Prices (Seasonally Adjus...        93287  2022
# 2732  GNP at Current Market Prices (Seasonally Adjus...        89542  2022
# 2733  GNP at Current Market Prices (Seasonally Adjus...        93467  2022
# 2734  GNP at Current Market Prices (Seasonally Adjus...        88873  2023
# 2735  GNP at Current Market Prices (Seasonally Adjus...       102104  2023
#
#      Quarter No         Value
# 0             1   21283000000
# 1             2   22083000000
# 2             3   22529000000
# 3             4   22342000000
# 4             1   22989000000
# ...         ...           ...
# 2731          2   93287000000
# 2732          3   89542000000
# 2733          4   93467000000
# 2734          1   88873000000
# 2735          2  102104000000
#
# [2736 rows x 5 columns]

# %%
# we don't need the 'Value (Mn.)' column anymore
gdp_gnp_df.drop(['Value (Mn.)'], axis = 1, inplace = True)

gdp_gnp_df
# Out:
#                                         Statistic Label  Year Quarter No  \
# 0                          GVA at Constant Basic Prices  1995          1
# 1                          GVA at Constant Basic Prices  1995          2
# 2                          GVA at Constant Basic Prices  1995          3
# 3                          GVA at Constant Basic Prices  1995          4
# 4                          GVA at Constant Basic Prices  1996          1
# ...                                                 ...   ...        ...
# 2731  GNP at Current Market Prices (Seasonally Adjus...  2022          2
# 2732  GNP at Current Market Prices (Seasonally Adjus...  2022          3
# 2733  GNP at Current Market Prices (Seasonally Adjus...  2022          4
# 2734  GNP at Current Market Prices (Seasonally Adjus...  2023          1
# 2735  GNP at Current Market Prices (Seasonally Adjus...  2023          2
#
#              Value
# 0      21283000000
# 1      22083000000
# 2      22529000000
# 3      22342000000
# 4      22989000000
# ...            ...
# 2731   93287000000
# 2732   89542000000
# 2733   93467000000
# 2734   88873000000
# 2735  102104000000
#
# [2736 rows x 4 columns]

# %% [markdown]
# * Check and remove duplicates
# * Because I removed the 'Age Group' classification columns, I need to remove duplicates values

# %%
# Total number of rows and columns
print('gdp_gnp_df shape:')
print(gdp_gnp_df.shape)
print()

# Rows containing duplicate data
gdp_gnp_dup_rows_df = gdp_gnp_df[gdp_gnp_df.duplicated()]
print('Number of duplicate rows:')
print(gdp_gnp_dup_rows_df.shape)
print()

# Used to count the number of rows before removing the data
print('Row count before removing duplicates:')
print()
print(gdp_gnp_df.count())
print()

# Dropping the duplicates
gdp_gnp_df = gdp_gnp_df.drop_duplicates()

# Counting the number of rows after removing duplicates.
print('Row count after removing duplicates:')
print()
print(gdp_gnp_df.count())
print()
# Out:
# gdp_gnp_df shape:
# (2736, 4)
#
# Number of duplicate rows:
# (0, 4)
#
# Row count before removing duplicates:
#
# Statistic Label    2736
# Year               2736
# Quarter No         2736
# Value              2736
# dtype: int64
#
# Row count after removing duplicates:
#
# Statistic Label    2736
# Year               2736
# Quarter No         2736
# Value              2736
# dtype: int64

# %%
# Convert selected columns to 'int'
gdp_gnp_df['Year'] = gdp_gnp_df['Year'].astype('int64')

# Validate the results
gdp_gnp_df.dtypes
# Out:
# Statistic Label    object
# Year                int64
# Quarter No         object
# Value               int64
# dtype: object

# %%
# Use pivot_table to aggregate the 'Value' column by sum for each combination of 'Year' and 'Statistic Label'
gdp_gnp_pivot_df = gdp_gnp_df.pivot_table(index = 'Year', columns = 'Statistic Label', values = 'Value', aggfunc = 'sum')

# we don't need the 'Value (Mn.)' column anymore
gdp_gnp_pivot_df.drop(['GDP at Constant Market Prices (Seasonally Adjusted)', 
                 'GDP at Current Market Prices', 
                 'GDP at Current Market Prices (Seasonally Adjusted)', 
                 'GNP at Constant Market Prices (Seasonally Adjusted)', 
                 'GNP at Current Market Prices', 
                 'GNP at Current Market Prices (Seasonally Adjusted)', 
                 'GVA at Constant Basic Prices (Seasonally Adjusted)',
                 'GVA at Current Basic Prices', 
                 'GVA at Current Basic Prices (Seasonally Adjusted)', 
                 'Net Factor Income from Rest of World', 
                 'Net Factor Income from Rest of World (Seasonally Adjusted)', 
                 'Net Factor Income from Rest of World at Current Prices', 
                 'Net Factor Income from Rest of World at Current Prices (Seasonally Adjusted)', 
                 'Subsidies on Products', 
                 'Subsidies on Products (chain linked annually ref to 2019) (Seasonally Adjusted)', 
                 'Subsidies on Products at Current Prices', 
                 'Subsidies on Products at Current Prices (Seasonally Adjusted)', 
                 'Taxes on Products', 
                 'Taxes on Products (Seasonally Adjusted)', 
                 'Taxes on Products at Current Prices', 
                 'Taxes on Products at Current Prices (Seasonally Adjusted)'], axis = 1, inplace = True)

# Rename columns
gdp_gnp_pivot_df.rename(columns = {'GDP at Constant Market Prices': 'GDP', 
                                   'GNP at Constant Market Prices': 'GNP',
                                  'GVA at Constant Basic Prices': 'GVA'}, inplace = True)

gdp_gnp_pivot_df
# Out:
# Statistic Label           GDP           GNP           GVA
# Year
# 1995              96861000000   93108000000   88237000000
# 1996             104008000000   99625000000   94508000000
# 1997             115473000000  109294000000  104317000000
# 1998             125594000000  117567000000  112817000000
# 1999             138819000000  127088000000  123893000000
# 2000             151873000000  138791000000  135161000000
# 2001             159932000000  141356000000  143313000000
# 2002             169366000000  144707000000  152258000000
# 2003             174471000000  151555000000  156260000000
# 2004             186315000000  162276000000  166155000000
# 2005             197008000000  171101000000  174006000000
# 2006             206834000000  180814000000  181212000000
# 2007             217818000000  187527000000  192763000000
# 2008             208051000000  180139000000  187712000000
# 2009             197450000000  165003000000  180811000000
# 2010             200772000000  171011000000  184048000000
# 2011             203343000000  166763000000  187495000000
# 2012             203080000000  166053000000  187102000000
# 2013             205466000000  175230000000  188780000000
# 2014             223606000000  191298000000  205224000000
# 2015             278334000000  215863000000  258944000000
# 2016             283248000000  231361000000  262607000000
# 2017             309621000000  246086000000  288222000000
# 2018             335849000000  260724000000  313888000000
# 2019             353641000000  273940000000  330084000000
# 2020             377042000000  283779000000  356769000000
# 2021             434069000000  323313000000  409387000000
# 2022             475016000000  335904000000  450216000000
# 2023             228329000000  162392000000  216858000000

# %%
gdp_gnp_pivot_df = gdp_gnp_pivot_df.loc[1998:2022]

gdp_gnp_pivot_df
# Out:
# Statistic Label           GDP           GNP           GVA
# Year
# 1998             125594000000  117567000000  112817000000
# 1999             138819000000  127088000000  123893000000
# 2000             151873000000  138791000000  135161000000
# 2001             159932000000  141356000000  143313000000
# 2002             169366000000  144707000000  152258000000
# 2003             174471000000  151555000000  156260000000
# 2004             186315000000  162276000000  166155000000
# 2005             197008000000  171101000000  174006000000
# 2006             206834000000  180814000000  181212000000
# 2007             217818000000  187527000000  192763000000
# 2008             208051000000  180139000000  187712000000
# 2009             197450000000  165003000000  180811000000
# 2010             200772000000  171011000000  184048000000
# 2011             203343000000  166763000000  187495000000
# 2012             203080000000  166053000000  187102000000
# 2013             205466000000  175230000000  188780000000
# 2014             223606000000  191298000000  205224000000
# 2015             278334000000  215863000000  258944000000
# 2016             283248000000  231361000000  262607000000
# 2017             309621000000  246086000000  288222000000
# 2018             335849000000  260724000000  313888000000
# 2019             353641000000  273940000000  330084000000
# 2020             377042000000  283779000000  356769000000
# 2021             434069000000  323313000000  409387000000
# 2022             475016000000  335904000000  450216000000

# %%
gdp_gnp_df = gdp_gnp_df.groupby(['Year', 'Statistic Label'])['Value'].sum().reset_index()
gdp_gnp_df
# Out:
#      Year                                    Statistic Label        Value
# 0    1995                      GDP at Constant Market Prices  96861000000
# 1    1995  GDP at Constant Market Prices (Seasonally Adju...  99549000000
# 2    1995                       GDP at Current Market Prices  54759000000
# 3    1995  GDP at Current Market Prices (Seasonally Adjus...  54635000000
# 4    1995                      GNP at Constant Market Prices  93108000000
# ..    ...                                                ...          ...
# 691  2023  Subsidies on Products at Current Prices (Seaso...   -896000000
# 692  2023                                  Taxes on Products  12223000000
# 693  2023            Taxes on Products (Seasonally Adjusted)  12934000000
# 694  2023                Taxes on Products at Current Prices  13802000000
# 695  2023  Taxes on Products at Current Prices (Seasonall...  14710000000
#
# [696 rows x 3 columns]

# %%
# Setting the index to 'Year'
gdp_gnp_df.set_index('Year', inplace = True)

# %% [markdown]
# ### Combining the datasets

# %%
outer_merged_df = pd.merge(pop_change_pivot_df, pop_est_pivot_df, how = "outer",
on = ["Year"])
outer_merged_df.head()
# Out:
#       Annual births  Annual deaths  Emigrants  Immigrants  Natural increase  \
# Year
# 1998        52700.0        31200.0    28600.0     46000.0           21500.0
# 1999        53700.0        32400.0    31500.0     48900.0           21200.0
# 2000        54000.0        32100.0    26600.0     52600.0           21800.0
# 2001        55100.0        30200.0    26200.0     59000.0           24800.0
# 2002        58100.0        29300.0    25600.0     66900.0           28800.0
#
#       Net migration  Population  Population change     Female       Male
# Year
# 1998        17400.0   3703100.0            38800.0  1864200.0  1838900.0
# 1999        17300.0   3741600.0            38500.0  1883000.0  1858600.0
# 2000        26000.0   3789500.0            47900.0  1906600.0  1882900.0
# 2001        32800.0   3847200.0            57700.0  1934100.0  1913100.0
# 2002        41300.0   3917200.0            70000.0  1971000.0  1946200.0

# %%
outer_merged_df = pd.merge(outer_merged_df, gdp_gnp_pivot_df, how = "outer",
on = ["Year"])
outer_merged_df.head()
# Out:
#       Annual births  Annual deaths  Emigrants  Immigrants  Natural increase  \
# Year
# 1998        52700.0        31200.0    28600.0     46000.0           21500.0
# 1999        53700.0        32400.0    31500.0     48900.0           21200.0
# 2000        54000.0        32100.0    26600.0     52600.0           21800.0
# 2001        55100.0        30200.0    26200.0     59000.0           24800.0
# 2002        58100.0        29300.0    25600.0     66900.0           28800.0
#
#       Net migration  Population  Population change     Female       Male  \
# Year
# 1998        17400.0   3703100.0            38800.0  1864200.0  1838900.0
# 1999        17300.0   3741600.0            38500.0  1883000.0  1858600.0
# 2000        26000.0   3789500.0            47900.0  1906600.0  1882900.0
# 2001        32800.0   3847200.0            57700.0  1934100.0  1913100.0
# 2002        41300.0   3917200.0            70000.0  1971000.0  1946200.0
#
#                GDP           GNP           GVA
# Year
# 1998  125594000000  117567000000  112817000000
# 1999  138819000000  127088000000  123893000000
# 2000  151873000000  138791000000  135161000000
# 2001  159932000000  141356000000  143313000000
# 2002  169366000000  144707000000  152258000000

# %%
outer_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 1998 to 2022
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Annual births      25 non-null     float64
#  1   Annual deaths      25 non-null     float64
#  2   Emigrants          25 non-null     float64
#  3   Immigrants         25 non-null     float64
#  4   Natural increase   25 non-null     float64
#  5   Net migration      25 non-null     float64
#  6   Population         25 non-null     float64
#  7   Population change  25 non-null     float64
#  8   Female             25 non-null     float64
#  9   Male               25 non-null     float64
#  10  GDP                25 non-null     int64
#  11  GNP                25 non-null     int64
#  12  GVA                25 non-null     int64
# dtypes: float64(10), int64(3)
# memory usage: 2.7 KB

# %%
# Convert selected columns to int64 data type
columns_to_convert = ['Annual births', 'Annual deaths', 'Emigrants', 'Immigrants','Natural increase', 'Net migration', 
                      'Population', 'Population change', 'Female', 'Male']

# Convert to int64 and update the dataset
outer_merged_df[columns_to_convert] = outer_merged_df[columns_to_convert].astype('int64')

# Display data types to confirm conversion
outer_merged_df[columns_to_convert].dtypes
# Out:
# Annual births        int64
# Annual deaths        int64
# Emigrants            int64
# Immigrants           int64
# Natural increase     int64
# Net migration        int64
# Population           int64
# Population change    int64
# Female               int64
# Male                 int64
# dtype: object

# %%
# Create new calculated columns to ensure that the data in the dataset is accurate
outer_merged_df['Calculated Natural Increase'] = outer_merged_df['Annual births'] - outer_merged_df['Annual deaths']
outer_merged_df['Calculated Net Migration Check'] = outer_merged_df['Immigrants'] - outer_merged_df['Emigrants']

# Compare calculated columsn to check if they are the same
outer_merged_df['Natural Increase Check'] = outer_merged_df['Calculated Natural Increase'] == outer_merged_df['Natural increase']
outer_merged_df['Net Migration Check'] = outer_merged_df['Calculated Net Migration Check'] == outer_merged_df['Net migration']

# Display the new columns to verify the calculations and comparisons
outer_merged_df.head(25)

## Clear to see that the calcs in the data aren't correct so I will use my calcs
# Out:
#       Annual births  Annual deaths  Emigrants  Immigrants  Natural increase  \
# Year
# 1998          52700          31200      28600       46000             21500
# 1999          53700          32400      31500       48900             21200
# 2000          54000          32100      26600       52600             21800
# 2001          55100          30200      26200       59000             24800
# 2002          58100          29300      25600       66900             28800
# 2003          60800          28900      29300       60000             31900
# 2004          62000          28600      26500       58500             33300
# 2005          61400          27900      29400       84600             33500
# 2006          61200          27000      36000      107800             34200
# 2007          66600          28400      46300      151100             38200
# 2008          73000          28000      49200      113500             44900
# 2009          75300          28600      72000       73700             46700
# 2010          77200          28400      69200       41800             48800
# 2011          75100          27700      80600       53300             47500
# 2012          73200          28700      83000       57300             44500
# 2013          69400          29800      81300       62700             39600
# 2014          68400          29200      75000       66500             39200
# 2015          66400          29900      70000       75900             36500
# 2016          65400          29800      66200       82300             35600
# 2017          63400          31300      56100       95300             32100
# 2018          61600          32000      51600       96000             29600
# 2019          60500          30900      53100       97100             29600
# 2020          59100          32400      50900       95600             26700
# 2021          57300          34300      52300       74100             23000
# 2022          59700          33600      56100      107800             26100
#
#       Net migration  Population  Population change   Female     Male  \
# Year
# 1998          17400     3703100              38800  1864200  1838900
# 1999          17300     3741600              38500  1883000  1858600
# 2000          26000     3789500              47900  1906600  1882900
# 2001          32800     3847200              57700  1934100  1913100
# 2002          41300     3917200              70000  1971000  1946200
# 2003          30700     3979900              62600  2002900  1976900
# 2004          32000     4045200              65300  2033300  2011900
# 2005          55100     4133800              88600  2072000  2061800
# 2006          71800     4232900             106000  2115600  2117300
# 2007         104800     4375800             142900  2184600  2191300
# 2008          64300     4485100             109200  2246500  2238600
# 2009           1600     4533400              48300  2276100  2257300
# 2010         -27500     4554800              21400  2292600  2262200
# 2011         -27400     4574900              20100  2304400  2270500
# 2012         -25700     4593700              18800  2318700  2275000
# 2013         -18700     4614700              21000  2328500  2286100
# 2014          -8500     4645400              30800  2346400  2299000
# 2015           5900     4687800              42300  2370100  2317700
# 2016          16200     4739600              51800  2393100  2346500
# 2017          39200     4810900              71300  2430100  2380800
# 2018          44400     4884900              74000  2465400  2419500
# 2019          44000     4958500              73600  2502200  2456300
# 2020          44700     5029900              71400  2538100  2491800
# 2021          21800     5074700              44800  2560600  2514000
# 2022          51700     5184000              77800  2622000  2562000
#
#                GDP           GNP           GVA  Calculated Natural Increase  \
# Year
# 1998  125594000000  117567000000  112817000000                        21500
# 1999  138819000000  127088000000  123893000000                        21300
# 2000  151873000000  138791000000  135161000000                        21900
# 2001  159932000000  141356000000  143313000000                        24900
# 2002  169366000000  144707000000  152258000000                        28800
# 2003  174471000000  151555000000  156260000000                        31900
# 2004  186315000000  162276000000  166155000000                        33400
# 2005  197008000000  171101000000  174006000000                        33500
# 2006  206834000000  180814000000  181212000000                        34200
# 2007  217818000000  187527000000  192763000000                        38200
# 2008  208051000000  180139000000  187712000000                        45000
# 2009  197450000000  165003000000  180811000000                        46700
# 2010  200772000000  171011000000  184048000000                        48800
# 2011  203343000000  166763000000  187495000000                        47400
# 2012  203080000000  166053000000  187102000000                        44500
# 2013  205466000000  175230000000  188780000000                        39600
# 2014  223606000000  191298000000  205224000000                        39200
# 2015  278334000000  215863000000  258944000000                        36500
# 2016  283248000000  231361000000  262607000000                        35600
# 2017  309621000000  246086000000  288222000000                        32100
# 2018  335849000000  260724000000  313888000000                        29600
# 2019  353641000000  273940000000  330084000000                        29600
# 2020  377042000000  283779000000  356769000000                        26700
# 2021  434069000000  323313000000  409387000000                        23000
# 2022  475016000000  335904000000  450216000000                        26100
#
#       Calculated Net Migration Check  Natural Increase Check  \
# Year
# 1998                           17400                    True
# 1999                           17400                   False
# 2000                           26000                   False
# 2001                           32800                   False
# 2002                           41300                    True
# 2003                           30700                    True
# 2004                           32000                   False
# 2005                           55200                    True
# 2006                           71800                    True
# 2007                          104800                    True
# 2008                           64300                   False
# 2009                            1700                    True
# 2010                          -27400                    True
# 2011                          -27300                   False
# 2012                          -25700                    True
# 2013                          -18600                    True
# 2014                           -8500                    True
# 2015                            5900                    True
# 2016                           16100                    True
# 2017                           39200                    True
# 2018                           44400                    True
# 2019                           44000                    True
# 2020                           44700                    True
# 2021                           21800                    True
# 2022                           51700                    True
#
#       Net Migration Check
# Year
# 1998                 True
# 1999                False
# 2000                 True
# 2001                 True
# 2002                 True
# 2003                 True
# 2004                 True
# 2005                False
# 2006                 True
# 2007                 True
# 2008                 True
# 2009                False
# 2010                False
# 2011                False
# 2012                 True
# 2013                False
# 2014                 True
# 2015                 True
# 2016                False
# 2017                 True
# 2018                 True
# 2019                 True
# 2020                 True
# 2021                 True
# 2022                 True

# %%
# Create new calculated columns to ensure that the data in the dataset is accurate
outer_merged_df['Calculated Population Change'] = outer_merged_df['Calculated Natural Increase'] + outer_merged_df['Calculated Net Migration Check']

# Compare calculated columsn to check if they are the same
outer_merged_df['Population Change Check'] = outer_merged_df['Calculated Population Change'] == outer_merged_df['Population change']

# Display the new columns to verify the calculations and comparisons
outer_merged_df.head(25)
# Out:
#       Annual births  Annual deaths  Emigrants  Immigrants  Natural increase  \
# Year
# 1998          52700          31200      28600       46000             21500
# 1999          53700          32400      31500       48900             21200
# 2000          54000          32100      26600       52600             21800
# 2001          55100          30200      26200       59000             24800
# 2002          58100          29300      25600       66900             28800
# 2003          60800          28900      29300       60000             31900
# 2004          62000          28600      26500       58500             33300
# 2005          61400          27900      29400       84600             33500
# 2006          61200          27000      36000      107800             34200
# 2007          66600          28400      46300      151100             38200
# 2008          73000          28000      49200      113500             44900
# 2009          75300          28600      72000       73700             46700
# 2010          77200          28400      69200       41800             48800
# 2011          75100          27700      80600       53300             47500
# 2012          73200          28700      83000       57300             44500
# 2013          69400          29800      81300       62700             39600
# 2014          68400          29200      75000       66500             39200
# 2015          66400          29900      70000       75900             36500
# 2016          65400          29800      66200       82300             35600
# 2017          63400          31300      56100       95300             32100
# 2018          61600          32000      51600       96000             29600
# 2019          60500          30900      53100       97100             29600
# 2020          59100          32400      50900       95600             26700
# 2021          57300          34300      52300       74100             23000
# 2022          59700          33600      56100      107800             26100
#
#       Net migration  Population  Population change   Female     Male  \
# Year
# 1998          17400     3703100              38800  1864200  1838900
# 1999          17300     3741600              38500  1883000  1858600
# 2000          26000     3789500              47900  1906600  1882900
# 2001          32800     3847200              57700  1934100  1913100
# 2002          41300     3917200              70000  1971000  1946200
# 2003          30700     3979900              62600  2002900  1976900
# 2004          32000     4045200              65300  2033300  2011900
# 2005          55100     4133800              88600  2072000  2061800
# 2006          71800     4232900             106000  2115600  2117300
# 2007         104800     4375800             142900  2184600  2191300
# 2008          64300     4485100             109200  2246500  2238600
# 2009           1600     4533400              48300  2276100  2257300
# 2010         -27500     4554800              21400  2292600  2262200
# 2011         -27400     4574900              20100  2304400  2270500
# 2012         -25700     4593700              18800  2318700  2275000
# 2013         -18700     4614700              21000  2328500  2286100
# 2014          -8500     4645400              30800  2346400  2299000
# 2015           5900     4687800              42300  2370100  2317700
# 2016          16200     4739600              51800  2393100  2346500
# 2017          39200     4810900              71300  2430100  2380800
# 2018          44400     4884900              74000  2465400  2419500
# 2019          44000     4958500              73600  2502200  2456300
# 2020          44700     5029900              71400  2538100  2491800
# 2021          21800     5074700              44800  2560600  2514000
# 2022          51700     5184000              77800  2622000  2562000
#
#                GDP           GNP           GVA  Calculated Natural Increase  \
# Year
# 1998  125594000000  117567000000  112817000000                        21500
# 1999  138819000000  127088000000  123893000000                        21300
# 2000  151873000000  138791000000  135161000000                        21900
# 2001  159932000000  141356000000  143313000000                        24900
# 2002  169366000000  144707000000  152258000000                        28800
# 2003  174471000000  151555000000  156260000000                        31900
# 2004  186315000000  162276000000  166155000000                        33400
# 2005  197008000000  171101000000  174006000000                        33500
# 2006  206834000000  180814000000  181212000000                        34200
# 2007  217818000000  187527000000  192763000000                        38200
# 2008  208051000000  180139000000  187712000000                        45000
# 2009  197450000000  165003000000  180811000000                        46700
# 2010  200772000000  171011000000  184048000000                        48800
# 2011  203343000000  166763000000  187495000000                        47400
# 2012  203080000000  166053000000  187102000000                        44500
# 2013  205466000000  175230000000  188780000000                        39600
# 2014  223606000000  191298000000  205224000000                        39200
# 2015  278334000000  215863000000  258944000000                        36500
# 2016  283248000000  231361000000  262607000000                        35600
# 2017  309621000000  246086000000  288222000000                        32100
# 2018  335849000000  260724000000  313888000000                        29600
# 2019  353641000000  273940000000  330084000000                        29600
# 2020  377042000000  283779000000  356769000000                        26700
# 2021  434069000000  323313000000  409387000000                        23000
# 2022  475016000000  335904000000  450216000000                        26100
#
#       Calculated Net Migration Check  Natural Increase Check  \
# Year
# 1998                           17400                    True
# 1999                           17400                   False
# 2000                           26000                   False
# 2001                           32800                   False
# 2002                           41300                    True
# 2003                           30700                    True
# 2004                           32000                   False
# 2005                           55200                    True
# 2006                           71800                    True
# 2007                          104800                    True
# 2008                           64300                   False
# 2009                            1700                    True
# 2010                          -27400                    True
# 2011                          -27300                   False
# 2012                          -25700                    True
# 2013                          -18600                    True
# 2014                           -8500                    True
# 2015                            5900                    True
# 2016                           16100                    True
# 2017                           39200                    True
# 2018                           44400                    True
# 2019                           44000                    True
# 2020                           44700                    True
# 2021                           21800                    True
# 2022                           51700                    True
#
#       Net Migration Check  Calculated Population Change  \
# Year
# 1998                 True                         38900
# 1999                False                         38700
# 2000                 True                         47900
# 2001                 True                         57700
# 2002                 True                         70100
# 2003                 True                         62600
# 2004                 True                         65400
# 2005                False                         88700
# 2006                 True                        106000
# 2007                 True                        143000
# 2008                 True                        109300
# 2009                False                         48400
# 2010                False                         21400
# 2011                False                         20100
# 2012                 True                         18800
# 2013                False                         21000
# 2014                 True                         30700
# 2015                 True                         42400
# 2016                False                         51700
# 2017                 True                         71300
# 2018                 True                         74000
# 2019                 True                         73600
# 2020                 True                         71400
# 2021                 True                         44800
# 2022                 True                         77800
#
#       Population Change Check
# Year
# 1998                    False
# 1999                    False
# 2000                     True
# 2001                     True
# 2002                    False
# 2003                     True
# 2004                    False
# 2005                    False
# 2006                     True
# 2007                    False
# 2008                    False
# 2009                    False
# 2010                     True
# 2011                     True
# 2012                     True
# 2013                     True
# 2014                    False
# 2015                    False
# 2016                    False
# 2017                     True
# 2018                     True
# 2019                     True
# 2020                     True
# 2021                     True
# 2022                     True

# %%
# Initialize the 'Population' column with the first value as 3703100
outer_merged_df.loc[1998, 'Calculated Population'] = 3703100

# Calculate the 'Population' for each subsequent year
for year in outer_merged_df.index[1:]:
    previous_year = year - 1
    outer_merged_df.loc[year, 'Calculated Population'] = outer_merged_df.loc[previous_year, 'Calculated Population'] + outer_merged_df.loc[year, 'Calculated Population Change']

# Display the first few rows of the updated DataFrame with 'Year' as index
outer_merged_df.head()
# Out:
#       Annual births  Annual deaths  Emigrants  Immigrants  Natural increase  \
# Year
# 1998          52700          31200      28600       46000             21500
# 1999          53700          32400      31500       48900             21200
# 2000          54000          32100      26600       52600             21800
# 2001          55100          30200      26200       59000             24800
# 2002          58100          29300      25600       66900             28800
#
#       Net migration  Population  Population change   Female     Male  \
# Year
# 1998          17400     3703100              38800  1864200  1838900
# 1999          17300     3741600              38500  1883000  1858600
# 2000          26000     3789500              47900  1906600  1882900
# 2001          32800     3847200              57700  1934100  1913100
# 2002          41300     3917200              70000  1971000  1946200
#
#                GDP           GNP           GVA  Calculated Natural Increase  \
# Year
# 1998  125594000000  117567000000  112817000000                        21500
# 1999  138819000000  127088000000  123893000000                        21300
# 2000  151873000000  138791000000  135161000000                        21900
# 2001  159932000000  141356000000  143313000000                        24900
# 2002  169366000000  144707000000  152258000000                        28800
#
#       Calculated Net Migration Check  Natural Increase Check  \
# Year
# 1998                           17400                    True
# 1999                           17400                   False
# 2000                           26000                   False
# 2001                           32800                   False
# 2002                           41300                    True
#
#       Net Migration Check  Calculated Population Change  \
# Year
# 1998                 True                         38900
# 1999                False                         38700
# 2000                 True                         47900
# 2001                 True                         57700
# 2002                 True                         70100
#
#       Population Change Check  Calculated Population
# Year
# 1998                    False              3703100.0
# 1999                    False              3741800.0
# 2000                     True              3789700.0
# 2001                     True              3847400.0
# 2002                    False              3917500.0

# %%
# we don't need columns anymore
outer_merged_df.drop(['Natural increase', 'Net migration', 'Natural Increase Check', 'Net Migration Check', 
                      'Population change', 'Population Change Check', 'Population'], axis = 1, inplace = True)

# Rename columns
outer_merged_df.rename(columns = {'Calculated Natural Increase': 'Natural Increase', 
                                   'Calculated Net Migration Check': 'Net Migration',
                                  'Calculated Population Change': 'Population Change',
                                 'Calculated Population': 'Population',
                                 'Annual births': 'Annual Births',
                                 'Annual deaths': 'Annual Deaths'}, inplace = True)

outer_merged_df
# Out:
#       Annual Births  Annual Deaths  Emigrants  Immigrants   Female     Male  \
# Year
# 1998          52700          31200      28600       46000  1864200  1838900
# 1999          53700          32400      31500       48900  1883000  1858600
# 2000          54000          32100      26600       52600  1906600  1882900
# 2001          55100          30200      26200       59000  1934100  1913100
# 2002          58100          29300      25600       66900  1971000  1946200
# 2003          60800          28900      29300       60000  2002900  1976900
# 2004          62000          28600      26500       58500  2033300  2011900
# 2005          61400          27900      29400       84600  2072000  2061800
# 2006          61200          27000      36000      107800  2115600  2117300
# 2007          66600          28400      46300      151100  2184600  2191300
# 2008          73000          28000      49200      113500  2246500  2238600
# 2009          75300          28600      72000       73700  2276100  2257300
# 2010          77200          28400      69200       41800  2292600  2262200
# 2011          75100          27700      80600       53300  2304400  2270500
# 2012          73200          28700      83000       57300  2318700  2275000
# 2013          69400          29800      81300       62700  2328500  2286100
# 2014          68400          29200      75000       66500  2346400  2299000
# 2015          66400          29900      70000       75900  2370100  2317700
# 2016          65400          29800      66200       82300  2393100  2346500
# 2017          63400          31300      56100       95300  2430100  2380800
# 2018          61600          32000      51600       96000  2465400  2419500
# 2019          60500          30900      53100       97100  2502200  2456300
# 2020          59100          32400      50900       95600  2538100  2491800
# 2021          57300          34300      52300       74100  2560600  2514000
# 2022          59700          33600      56100      107800  2622000  2562000
#
#                GDP           GNP           GVA  Natural Increase  \
# Year
# 1998  125594000000  117567000000  112817000000             21500
# 1999  138819000000  127088000000  123893000000             21300
# 2000  151873000000  138791000000  135161000000             21900
# 2001  159932000000  141356000000  143313000000             24900
# 2002  169366000000  144707000000  152258000000             28800
# 2003  174471000000  151555000000  156260000000             31900
# 2004  186315000000  162276000000  166155000000             33400
# 2005  197008000000  171101000000  174006000000             33500
# 2006  206834000000  180814000000  181212000000             34200
# 2007  217818000000  187527000000  192763000000             38200
# 2008  208051000000  180139000000  187712000000             45000
# 2009  197450000000  165003000000  180811000000             46700
# 2010  200772000000  171011000000  184048000000             48800
# 2011  203343000000  166763000000  187495000000             47400
# 2012  203080000000  166053000000  187102000000             44500
# 2013  205466000000  175230000000  188780000000             39600
# 2014  223606000000  191298000000  205224000000             39200
# 2015  278334000000  215863000000  258944000000             36500
# 2016  283248000000  231361000000  262607000000             35600
# 2017  309621000000  246086000000  288222000000             32100
# 2018  335849000000  260724000000  313888000000             29600
# 2019  353641000000  273940000000  330084000000             29600
# 2020  377042000000  283779000000  356769000000             26700
# 2021  434069000000  323313000000  409387000000             23000
# 2022  475016000000  335904000000  450216000000             26100
#
#       Net Migration  Population Change  Population
# Year
# 1998          17400              38900   3703100.0
# 1999          17400              38700   3741800.0
# 2000          26000              47900   3789700.0
# 2001          32800              57700   3847400.0
# 2002          41300              70100   3917500.0
# 2003          30700              62600   3980100.0
# 2004          32000              65400   4045500.0
# 2005          55200              88700   4134200.0
# 2006          71800             106000   4240200.0
# 2007         104800             143000   4383200.0
# 2008          64300             109300   4492500.0
# 2009           1700              48400   4540900.0
# 2010         -27400              21400   4562300.0
# 2011         -27300              20100   4582400.0
# 2012         -25700              18800   4601200.0
# 2013         -18600              21000   4622200.0
# 2014          -8500              30700   4652900.0
# 2015           5900              42400   4695300.0
# 2016          16100              51700   4747000.0
# 2017          39200              71300   4818300.0
# 2018          44400              74000   4892300.0
# 2019          44000              73600   4965900.0
# 2020          44700              71400   5037300.0
# 2021          21800              44800   5082100.0
# 2022          51700              77800   5159900.0

# %%
# Rename columns
outer_merged_df.rename(columns = {'Annual births': 'Annual Births',
                                 'Annual deaths': 'Annual Deaths',
                                 'Natural increase': 'Natural Increase',
                                 'Net migration': 'Net Migration',
                                 'Population change': 'Population Change'}, inplace = True)

# %%
# Reorder single-level columns
reordered_columns = ['Population', 'Population Change', 'Annual Births', 'Annual Deaths', 'Natural Increase',
                    'Immigrants', 'Emigrants', 'Net Migration', 'Male', 'Female', 'GDP', 'GNP', 'GVA']

outer_merged_df = outer_merged_df[reordered_columns]

outer_merged_df
# Out:
#       Population  Population Change  Annual Births  Annual Deaths  \
# Year
# 1998   3703100.0              38900          52700          31200
# 1999   3741800.0              38700          53700          32400
# 2000   3789700.0              47900          54000          32100
# 2001   3847400.0              57700          55100          30200
# 2002   3917500.0              70100          58100          29300
# 2003   3980100.0              62600          60800          28900
# 2004   4045500.0              65400          62000          28600
# 2005   4134200.0              88700          61400          27900
# 2006   4240200.0             106000          61200          27000
# 2007   4383200.0             143000          66600          28400
# 2008   4492500.0             109300          73000          28000
# 2009   4540900.0              48400          75300          28600
# 2010   4562300.0              21400          77200          28400
# 2011   4582400.0              20100          75100          27700
# 2012   4601200.0              18800          73200          28700
# 2013   4622200.0              21000          69400          29800
# 2014   4652900.0              30700          68400          29200
# 2015   4695300.0              42400          66400          29900
# 2016   4747000.0              51700          65400          29800
# 2017   4818300.0              71300          63400          31300
# 2018   4892300.0              74000          61600          32000
# 2019   4965900.0              73600          60500          30900
# 2020   5037300.0              71400          59100          32400
# 2021   5082100.0              44800          57300          34300
# 2022   5159900.0              77800          59700          33600
#
#       Natural Increase  Immigrants  Emigrants  Net Migration     Male  \
# Year
# 1998             21500       46000      28600          17400  1838900
# 1999             21300       48900      31500          17400  1858600
# 2000             21900       52600      26600          26000  1882900
# 2001             24900       59000      26200          32800  1913100
# 2002             28800       66900      25600          41300  1946200
# 2003             31900       60000      29300          30700  1976900
# 2004             33400       58500      26500          32000  2011900
# 2005             33500       84600      29400          55200  2061800
# 2006             34200      107800      36000          71800  2117300
# 2007             38200      151100      46300         104800  2191300
# 2008             45000      113500      49200          64300  2238600
# 2009             46700       73700      72000           1700  2257300
# 2010             48800       41800      69200         -27400  2262200
# 2011             47400       53300      80600         -27300  2270500
# 2012             44500       57300      83000         -25700  2275000
# 2013             39600       62700      81300         -18600  2286100
# 2014             39200       66500      75000          -8500  2299000
# 2015             36500       75900      70000           5900  2317700
# 2016             35600       82300      66200          16100  2346500
# 2017             32100       95300      56100          39200  2380800
# 2018             29600       96000      51600          44400  2419500
# 2019             29600       97100      53100          44000  2456300
# 2020             26700       95600      50900          44700  2491800
# 2021             23000       74100      52300          21800  2514000
# 2022             26100      107800      56100          51700  2562000
#
#        Female           GDP           GNP           GVA
# Year
# 1998  1864200  125594000000  117567000000  112817000000
# 1999  1883000  138819000000  127088000000  123893000000
# 2000  1906600  151873000000  138791000000  135161000000
# 2001  1934100  159932000000  141356000000  143313000000
# 2002  1971000  169366000000  144707000000  152258000000
# 2003  2002900  174471000000  151555000000  156260000000
# 2004  2033300  186315000000  162276000000  166155000000
# 2005  2072000  197008000000  171101000000  174006000000
# 2006  2115600  206834000000  180814000000  181212000000
# 2007  2184600  217818000000  187527000000  192763000000
# 2008  2246500  208051000000  180139000000  187712000000
# 2009  2276100  197450000000  165003000000  180811000000
# 2010  2292600  200772000000  171011000000  184048000000
# 2011  2304400  203343000000  166763000000  187495000000
# 2012  2318700  203080000000  166053000000  187102000000
# 2013  2328500  205466000000  175230000000  188780000000
# 2014  2346400  223606000000  191298000000  205224000000
# 2015  2370100  278334000000  215863000000  258944000000
# 2016  2393100  283248000000  231361000000  262607000000
# 2017  2430100  309621000000  246086000000  288222000000
# 2018  2465400  335849000000  260724000000  313888000000
# 2019  2502200  353641000000  273940000000  330084000000
# 2020  2538100  377042000000  283779000000  356769000000
# 2021  2560600  434069000000  323313000000  409387000000
# 2022  2622000  475016000000  335904000000  450216000000

# %% [markdown]
# * now all the values have been validated and the dataset is clean to begin proper analysis

# %% [markdown]
# * Identifying null values

# %%
# Finding the null values
print(outer_merged_df.isnull().sum())
# Out:
# Population           0
# Population Change    0
# Annual Births        0
# Annual Deaths        0
# Natural Increase     0
# Immigrants           0
# Emigrants            0
# Net Migration        0
# Male                 0
# Female               0
# GDP                  0
# GNP                  0
# GVA                  0
# dtype: int64

# %% [markdown]
# Columns
#
# 1. Year: The year the data was collected.
# 2. Population: The total population.
# 3. Population Change: The change in population from the previous year.
# 4. Annual Births: The number of births in that year.
# 5. Annual Deaths: The number of deaths in that year.
# 6. Natural Increase: The natural increase in population (Births - Deaths).
# 7. Immigrants: The number of immigrants that year.
# 8. Emigrants: The number of emigrants that year.
# 9. Net Migration: The net migration (Immigrants - Emigrants).
# 10. Male: The male population.
# 11. Female: The female population.
# 12. GDP: Gross Domestic Product.
# 13. GNP: Gross National Product.
# 14. GVA: Gross Value Added.

# %% [markdown]
# ### File Export

# %%
# Exporting each of the cleaned original datasets
pop_change_df.to_csv('pop_change_df.csv')
pop_est_df.to_csv('pop_est_df.csv')
gdp_gnp_df.to_csv('gdp_gnp_df.csv')

# Exporting each of the cleaned pivoted datasets
pop_change_pivot_df.to_csv('pop_change_pivot_df.csv')
pop_est_pivot_df.to_csv('pop_est_pivot_df.csv')
gdp_gnp_pivot_df.to_csv('gdp_gnp_pivot_df.csv')

# Exporting the merged cleaned pivoted dataset
outer_merged_df.to_csv('outer_merged_df.csv')

# %% [markdown]
# ## Statistical analysis

# %%
# Generate descriptive statistics for numerical attributes
outer_merged_df.describe()
# Out:
#          Population  Population Change  Annual Births  Annual Deaths  \
# count  2.500000e+01          25.000000      25.000000      25.000000
# mean   4.449408e+06       59828.000000   63624.000000   30024.000000
# std    4.473460e+05       30486.042161    7166.605426    1949.418717
# min    3.703100e+06       18800.000000   52700.000000   27000.000000
# 25%    4.045500e+06       38900.000000   59100.000000   28600.000000
# 50%    4.562300e+06       57700.000000   61600.000000   29800.000000
# 75%    4.747000e+06       73600.000000   68400.000000   31300.000000
# max    5.159900e+06      143000.000000   77200.000000   34300.000000
#
#        Natural Increase     Immigrants     Emigrants  Net Migration  \
# count         25.000000      25.000000     25.000000      25.000000
# mean       33600.000000   77132.000000  50904.000000   26228.000000
# std         8489.895955   25963.848585  19729.831052   32668.492976
# min        21300.000000   41800.000000  25600.000000  -27400.000000
# 25%        26700.000000   58500.000000  29400.000000    5900.000000
# 50%        33400.000000   73700.000000  51600.000000   30700.000000
# 75%        39200.000000   95600.000000  69200.000000   44400.000000
# max        48800.000000  151100.000000  83000.000000  104800.000000
#
#                Male        Female           GDP           GNP           GVA
# count  2.500000e+01  2.500000e+01  2.500000e+01  2.500000e+01  2.500000e+01
# mean   2.207048e+06  2.238484e+06  2.406647e+11  1.963700e+11  2.211651e+11
# std    2.176835e+05  2.290064e+05  9.210513e+10  5.978024e+10  8.976293e+10
# min    1.838900e+06  1.864200e+06  1.255940e+11  1.175670e+11  1.128170e+11
# 25%    2.011900e+06  2.033300e+06  1.863150e+11  1.622760e+11  1.661550e+11
# 50%    2.262200e+06  2.292600e+06  2.054660e+11  1.752300e+11  1.874950e+11
# 75%    2.346500e+06  2.393100e+06  2.832480e+11  2.313610e+11  2.626070e+11
# max    2.562000e+06  2.622000e+06  4.750160e+11  3.359040e+11  4.502160e+11

# %% [markdown]
# Key Statistics:
# Year:
#
# Count: 25 years of data
# Mean: The average year is 2010
# Standard Deviation: Approximately 7.36 years
# Range: From 1998 to 2022
# Population:
#
# Count: 25 records
# Mean: About 4.45 million
# Standard Deviation: Approximately 447,346
# Range: From 3.7 million to 5.16 million
# Population Change:
#
# Mean: 59,828 people added per year
# Standard Deviation: Approximately 30,486
# Minimum: 18,800, Maximum: 143,000
# Annual Births and Deaths:
#
# Mean Births: Approximately 63,624
# Mean Deaths: Approximately 30,024
# Natural Increase (Births - Deaths): Mean is about 33,600
# Immigrants and Emigrants:
#
# Mean Immigrants: About 77,132
# Mean Emigrants: About 50,904
# Net Migration: Mean is about 26,228
# Gender Distribution:
#
# Mean Male Population: About 2.21 million
# Mean Female Population: About 2.24 million
# Both Sexes: Approximately 4.45 million (consistent with 'Population')
# Economic Indicators (GDP, GNP, GVA):
#
# Mean GDP: About 240.6 billion
# Mean GNP: About 196.4 billion
# Mean GVA: About 221.2 billion
# Standard Deviation:
#
# The standard deviation values indicate the dispersion for each variable. For example, the standard deviation for 'Population' is 447,346, which is moderate, suggesting a moderate variability over the years.
# Quartiles (25%, 50%, 75%):
#
# These provide an idea of the distribution of the data. For instance, 25% of the data points for 'Population' are below 4.05 million, and 75% are below 4.75 million.

# %% [markdown]
# Net Migration:
#
# The minimum value for net migration is negative (-27,400), which implies more people left than arrived in that specific year. This is a point worth investigating further to understand what might have caused this outflow.
#
# Population Change:
#
# The maximum value for population change is 143,000, which is significantly higher than the mean of 59,828. This could be due to an exceptionally high number of immigrants or births that year, or possibly an error in the data.
#
# Economic Indicators (GDP, GNP, GVA):
#
# The standard deviations for these economic variables are quite high, indicating a lot of variability. This may be due to economic cycles.
#
# Annual Births and Deaths:
#
# The standard deviation for annual births is approximately 7,166, which is relatively high considering the mean is 63,624. This could indicate specific years where the birth rate was unusually high or low.
#
# Gender Distribution:
#
# The mean populations for males and females are relatively close, but it might be worth exploring if there are any years where there is a significant disparity between the two.

# %%
p = outer_merged_df.hist(figsize = (20,20))

# %%
# Setting the aesthetic style for the plots
sns.set(style ="whitegrid")

# Creating a figure and axis objects
fig, axes = plt.subplots(nrows = 7, ncols = 2, figsize=(10, 15))

# Flattening the axis array for easy iteration
axes = axes.flatten()

# Looping through each column to create box plots
for i, column in enumerate(outer_merged_df.columns):
    sns.boxplot(x=outer_merged_df[column], ax=axes[i], color='skyblue')
    axes[i].set_title(f'Box Plot of {column}', fontsize = 14)
    axes[i].set_xlabel('')

# Removing any extra subplots
for i in range(len(outer_merged_df.columns), len(axes)):
    fig.delaxes(axes[i])

# Enhancing the layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Population: No skew
#
# Population Change: Positive skew, suggesting a rising trend in population over the years. One significant outlier.
#
# Annual Births:  Slightly positive skew, suggesting there have been more years with higher annual births.
#
# Annual Deaths: Slightly positive skew, suggesting there have been more years with higher annual deaths.
#
# Natural Increase: Slightly positive skew, suggesting there have been more years with a higher natural increase.
#
# Immigrants: Positive skew, suggesting more instances of higher immigration rates in certain years.
#
# Emigrants: Positive skew, suggesting more instances of higher emigration rates in certain years.
#
# Net Migration: No real skew suggesting that net migration has remained fairly consistent over the years. One significant outlier to investigate and understand.
#
# Male: Slightly positive skew, suggesting the male population seems to have increased over the years.
#
# Female: Slightly positive skew, mirrors that of the male population showing a gradual increase, generally a little higher than the male population.
#
# Both Sexes: Positive skew, suggesting a rising trend in population over the years. One significant outlier.
#
# GFP: Positive skew, suggesting economic growth over the years. Two outliers.
#
# GNP: Positive skew, suggesting economic growth over the years. One outlier.
#
# GVA: Positive skew, suggesting economic growth over the years. Two outliers.

# %%
# Creating a single figure for comparing 'Annual Births', 'Annual Deaths', and 'Natural Increase'
plt.figure(figsize=(10, 8))

# Melting the dataframe to long format for easy plotting
population_df = outer_merged_df[['Annual Births', 'Annual Deaths']].melt(var_name='Population Metrics', value_name='Value')

# Creating the box plot
sns.boxplot(x='Value', y='Population Metrics', data=population_df, palette='pastel')
plt.title('Box Plot Comparison of Annual Births, Annual Deaths, and Natural Increase', fontsize=16)
plt.xlabel('Population Metrics', fontsize=14)
plt.ylabel('Value', fontsize=14)

# Displaying the plot
plt.show()

# %% [markdown]
# Interpretation:
# Annual Births: This box plot has the highest median and the widest range among the three metrics, indicating that the number of annual births is generally higher and more variable.
#
# Annual Deaths: The box plot for annual deaths has the lowest median and the narrowest range. This suggests that the number of annual deaths is generally lower than the number of annual births and natural increase, with less variability.
#
# Natural Increase: The natural increase (annual births minus annual deaths) has a median that lies between that of annual births and annual deaths. The range is also intermediate, indicating a moderate level of variability.
#
# In summary, the box plots indicate that the number of annual births tends to be significantly higher than the number of annual deaths, leading to a positive natural increase. The variability in natural increase is also moderate compared to the other two metrics.

# %%
# Creating a single figure for comparing 'Immigrants', 'Emigrants', and 'Net Migration'
plt.figure(figsize=(10, 8))

# Melting the dataframe to long format for easy plotting
migration_df = outer_merged_df[['Immigrants', 'Emigrants']].melt(var_name='Migration Metrics', value_name='Value')

# Creating the box plot
sns.boxplot(x='Value', y='Migration Metrics', data=migration_df, palette='pastel')
plt.title('Box Plot Comparison of Immigrants, Emigrants, and Net Migration', fontsize=16)
plt.xlabel('Migration Metrics', fontsize=14)
plt.ylabel('Value', fontsize=14)

# Displaying the plot
plt.show()

# %% [markdown]
# The diagram above offers a side-by-side comparison of the box plots for 'Immigrants', 'Emigrants', and 'Net Migration'.
#
# Interpretation:
# Immigrants: This box plot has the highest median among the three metrics, indicating that the number of immigrants is generally higher. The range is also relatively wide, suggesting variability in immigration rates over the years.
#
# Emigrants: The box plot for emigrants has a median lower than that of immigrants but higher than net migration. The range is slightly narrower, indicating less variability in the number of people leaving the country compared to those entering.
#
# Net Migration: Net Migration, calculated as immigrants minus emigrants, has the narrowest range and lowest median. This suggests that net migration rates are generally positive but smaller in magnitude compared to the individual counts of immigrants and emigrants.
#
# In summary, the number of immigrants tends to be higher than the number of emigrants, resulting in generally positive net migration. The variability in net migration is also lower than the other two metrics, indicating more stable trends.

# %%
# Creating a single figure for comparing 'Male', 'Female', and 'Both Sexes'
plt.figure(figsize=(10, 8))

# Melting the dataframe to long format for easy plotting
gender_df = outer_merged_df[['Male', 'Female']].melt(var_name='Gender Metrics', value_name='Value')

# Creating the box plot
sns.boxplot(x = 'Value', y = 'Gender Metrics', data=gender_df, palette='pastel')
plt.title('Box Plot Comparison of Male, Female, and Both Sexes Populations', fontsize=16)
plt.xlabel('Gender Metrics', fontsize=14)
plt.ylabel('Value', fontsize=14)

# Displaying the plot
plt.show()

# %% [markdown]
# The diagram above presents a side-by-side comparison of the box plots for 'Male', 'Female', and 'Both Sexes' populations.
#
# Interpretation:
# Male: The box plot for the male population has a slightly lower median compared to the female population. The range is similar, suggesting a comparable level of variability in the male population over the years.
#
# Female: This box plot has a slightly higher median, indicating that the female population is generally a bit larger than the male population. The range is similar to that of the male population, indicating comparable variability.
#
# Both Sexes: As expected, the 'Both Sexes' metric has a median that is the sum of the male and female medians, and its range is also the largest. This plot essentially captures the total population and shows a stable, increasing trend over the years.
#
# In summary, the male and female populations are quite similar in size, with the female population being slightly larger. Both show similar levels of variability over the years, and the total population ('Both Sexes') has been steadily increasing.

# %%
# Creating a single figure for comparing 'Natural Increase', 'Net Migration', and 'Population Change'
plt.figure(figsize=(10, 8))

# Melting the dataframe to long format for easy plotting
change_df = outer_merged_df[['Natural Increase', 'Net Migration', 'Population Change']].melt(var_name='Change Metrics', value_name='Value')

# Creating the box plot
sns.boxplot(x='Value', y='Change Metrics', data=change_df, palette='pastel')
plt.title('Box Plot Comparison of Natural Increase, Net Migration, and Population Change', fontsize=16)
plt.xlabel('Change Metrics', fontsize=14)
plt.ylabel('Value', fontsize=14)

# Displaying the plot
plt.show()

# %% [markdown]
# The diagram above offers a side-by-side comparison of the box plots for 'Natural Increase', 'Net Migration', and 'Population Change'.
#
# Interpretation:
# Natural Increase: This metric, calculated as annual births minus annual deaths, has a fairly wide range and the highest median among the three. This suggests that natural increase is a significant component of population change.
#
# Net Migration: This metric, calculated as immigrants minus emigrants, has the narrowest range and the lowest median, indicating that while it contributes to population change, it is generally smaller in magnitude compared to natural increase.
#
# Population Change: This metric, essentially the sum of natural increase and net migration, has a median that lies between those of the other two metrics. The range is also intermediate, indicating a moderate level of variability in annual population change.
#
# In summary, natural increase appears to be the dominant factor contributing to population change, with net migration playing a smaller role. The overall population change is influenced by both factors and shows moderate variability.

# %%
# Creating a single figure for comparing 'GDP', 'GNP', and 'GVA'
plt.figure(figsize = (10, 8))

# Melting the dataframe to long format for easy plotting
economy_df = outer_merged_df[['GDP', 'GNP', 'GVA']].melt(var_name = 'Economic Indicator', value_name = 'Value')

# Creating the box plot
sns.boxplot(x = 'Value', y = 'Economic Indicator', data = economy_df, palette = 'pastel')
plt.title('Box Plot Comparison of GDP, GNP, and GVA', fontsize = 16)
plt.xlabel('Economic Indicator', fontsize = 14)
plt.ylabel('Value', fontsize = 14)

# Displaying the plot
plt.show()

# %% [markdown]
# Interpretation:
# GDP: The box plot for GDP has the widest range, suggesting higher variability in GDP values over the years. The median appears to be higher than that of GNP and GVA, indicating that GDP generally has higher values.
#
# GNP: The GNP box plot shows a slightly narrower range compared to GDP, with its median lying below that of GDP. This suggests that Gross National Product is generally lower than Gross Domestic Product in the given dataset.
#
# GVA: The Gross Value Added (GVA) has the narrowest range among the three, indicating less variability. Its median is the lowest, suggesting that GVA values are generally lower than both GDP and GNP.
#
# The box plots provide a useful visual comparison for understanding the distribution and central tendencies of these three economic indicators.

# %%
plt.figure(figsize=(20,10))
c = outer_merged_df.corr()
sns.heatmap(c,cmap="BrBG",annot=True) # "BrBG" color map and annotates each cell with the correlation coefficient
c
# Out:
#                    Population  Population Change  Annual Births  \
# Population           1.000000           0.000057       0.386138
# Population Change    0.000057           1.000000      -0.190597
# Annual Births        0.386138          -0.190597       1.000000
# Annual Deaths        0.290968          -0.147489      -0.605476
# Natural Increase     0.259141          -0.127024       0.983161
# Immigrants           0.435558           0.867191       0.048225
# Emigrants            0.684603          -0.458637       0.781030
# Net Migration       -0.067292           0.966205      -0.433368
# Male                 0.999540           0.023568       0.389874
# Female               0.999347          -0.019115       0.371031
# GDP                  0.874997           0.159192      -0.061535
# GNP                  0.882374           0.190797      -0.053097
# GVA                  0.876962           0.135302      -0.059645
#
#                    Annual Deaths  Natural Increase  Immigrants  Emigrants  \
# Population              0.290968          0.259141    0.435558   0.684603
# Population Change      -0.147489         -0.127024    0.867191  -0.458637
# Annual Births          -0.605476          0.983161    0.048225   0.781030
# Annual Deaths           1.000000         -0.740719   -0.027585  -0.127142
# Natural Increase       -0.740719          1.000000    0.047042   0.688488
# Immigrants             -0.027585          0.047042    1.000000  -0.003751
# Emigrants              -0.127142          0.688488   -0.003751   1.000000
# Net Migration           0.054862         -0.378418    0.797033  -0.606922
# Male                    0.281093          0.264562    0.455709   0.677125
# Female                  0.312060          0.241545    0.417469   0.682851
# GDP                     0.594159         -0.188372    0.474199   0.296993
# GNP                     0.571788         -0.176113    0.505814   0.295037
# GVA                     0.605536         -0.189389    0.454481   0.307522
#
#                    Net Migration      Male    Female       GDP       GNP  \
# Population             -0.067292  0.999540  0.999347  0.874997  0.882374
# Population Change       0.966205  0.023568 -0.019115  0.159192  0.190797
# Annual Births          -0.433368  0.389874  0.371031 -0.061535 -0.053097
# Annual Deaths           0.054862  0.281093  0.312060  0.594159  0.571788
# Natural Increase       -0.378418  0.264562  0.241545 -0.188372 -0.176113
# Immigrants              0.797033  0.455709  0.417469  0.474199  0.505814
# Emigrants              -0.606922  0.677125  0.682851  0.296993  0.295037
# Net Migration           1.000000 -0.046761 -0.080611  0.197511  0.223819
# Male                   -0.046761  1.000000  0.998213  0.876399  0.884163
# Female                 -0.080611  0.998213  1.000000  0.881910  0.887457
# GDP                     0.197511  0.876399  0.881910  1.000000  0.996609
# GNP                     0.223819  0.884163  0.887457  0.996609  1.000000
# GVA                     0.175481  0.877726  0.884536  0.999563  0.994750
#
#                         GVA
# Population         0.876962
# Population Change  0.135302
# Annual Births     -0.059645
# Annual Deaths      0.605536
# Natural Increase  -0.189389
# Immigrants         0.454481
# Emigrants          0.307522
# Net Migration      0.175481
# Male               0.877726
# Female             0.884536
# GDP                0.999563
# GNP                0.994750
# GVA                1.000000

# %%
import matplotlib.pyplot as plt

# Plot Population Growth Over Time
plt.figure(figsize=(10, 5))
plt.plot(outer_merged_df.index, outer_merged_df['Population'])
plt.title('Population Growth Over Time')
plt.xlabel('Year')
plt.ylabel('Population')
plt.grid(True)
plt.show()

# %%
# Plot Economic Indicators Over Time
plt.figure(figsize=(10, 5))
plt.plot(outer_merged_df.index, outer_merged_df['Natural Increase'], label='Natural Increase')
plt.plot(outer_merged_df.index, outer_merged_df['Net Migration'], label='Net Migration')
plt.plot(outer_merged_df.index, outer_merged_df['Population Change'], label='Population Change')
plt.title('Economic Indicators Over Time')
plt.xlabel('Year')
plt.ylabel('Economic Indicators')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Economic Indicators Over Time
plt.figure(figsize=(10, 5))
plt.plot(outer_merged_df.index, outer_merged_df['GDP'], label='GDP')
plt.plot(outer_merged_df.index, outer_merged_df['GNP'], label='GNP')
plt.plot(outer_merged_df.index, outer_merged_df['GVA'], label='GVA')
plt.title('Economic Indicators Over Time')
plt.xlabel('Year')
plt.ylabel('Economic Indicators')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Economic Indicators Over Time
plt.figure(figsize=(10, 5))
plt.plot(outer_merged_df.index, outer_merged_df['Male'], label='Male')
plt.plot(outer_merged_df.index, outer_merged_df['Female'], label='Female')
plt.title('Sexes Over Time')
plt.xlabel('Year')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create a figure and a set of subplots (dual axes)
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot Population against Year (left y-axis)
ax1.set_xlabel('Year')
ax1.set_ylabel('Population', color='tab:blue')
ax1.plot(outer_merged_df.index, outer_merged_df['Population'], color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create another y-axis for the Economic Indicators
ax2 = ax1.twinx()
ax2.set_ylabel('Economic Indicators', color='tab:red')
ax2.plot(outer_merged_df.index, outer_merged_df['GDP'], label='GDP', color='tab:orange')
ax2.plot(outer_merged_df.index, outer_merged_df['GNP'], label='GNP', color='tab:green')
ax2.plot(outer_merged_df.index, outer_merged_df['GVA'], label='GVA', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Add legend and grid
ax2.legend()
ax1.grid(True)

# Show the plot
plt.title('Population and Economic Indicators Over Time')
plt.show()

# %%
# Generate the scatter matrix (pairplot) using seaborn
sns.pairplot(outer_merged_df, diag_kind='kde')
plt.suptitle('Scatter Matrix for the Last 20 Years', y=1.02)
plt.show()
