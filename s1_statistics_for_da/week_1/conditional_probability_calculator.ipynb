# %% [markdown]
# # Bayes' Theorem Conditional Probability Calculator

# %%
from IPython.display import Image
Image(filename =r'conditional_probability_formula.png', width = 600, height = 300)

# %%
from IPython.display import Image
Image(filename =r'conditional_probability_formula_diagram.png', width = 600, height = 300)

# %% [markdown]
# If an order was chosen that does not meet specifications, what is the probability that it was received
# on time?

# %%
# Define probabilities for a two tree probability tree diagram
PA = 0.75
P_A = 0.25
tree_1_1_meets_spec = 0.8
tree_1_1_doesnt_meet_spec = 0.2
tree_1_2_meets_spec = 0.6
tree_1_2_doesnt_meet_spec = 0.4
# Out:
#   Cell In[12], line 2
#     P(A) = 0.75
#     ^
# SyntaxError: cannot assign to function call

# %%
# Calculate the probability that it doesn't meet specifications
# Work out the individual probability scenarios and add together
doesnt_meet_spec = (tree_1_on_time * tree_1_1_doesnt_meet_spec) + (tree_1_late * tree_1_2_doesnt_meet_spec)

# %%
# Calculate the conditional probability P(B|A) i.e. the probability of event B occuring given that event A has occured
# Event B is that it arrives on time
# Event A is that it didn't meet requirements

on_time_doesnt_meet_spec = (tree_1_1_doesnt_meet_spec * tree_1_on_time) / doesnt_meet_spec

# %%
on_time_doesnt_meet_spec
# Out:
# 0.6000000000000001
