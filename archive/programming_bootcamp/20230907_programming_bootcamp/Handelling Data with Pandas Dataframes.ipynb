# %% [markdown]
# ![CCT%20Header.jpg](attachment:CCT%20Header.jpg)

# %% [markdown]
# ## Handelling Data with Pandas Dataframes

# %%
import pandas as pd
import seaborn as sns

# %%
diamonds_file = pd.read_csv("diamonds.csv")

# %%
diamonds_file
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds_url = pd.read_csv("https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/diamonds.csv")

# %%
diamonds_url
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds_df = sns.load_dataset('diamonds')

# %%
diamonds_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds_df_specific_cols = pd.read_csv("https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/diamonds.csv",usecols=['carat','cut','color','clarity'])

# %%
diamonds_df_specific_cols
# Out:
#        carat        cut color clarity
# 0       0.23      Ideal     E     SI2
# 1       0.21    Premium     E     SI1
# 2       0.23       Good     E     VS1
# 3       0.29    Premium     I     VS2
# 4       0.31       Good     J     SI2
# ...      ...        ...   ...     ...
# 53935   0.72      Ideal     D     SI1
# 53936   0.72       Good     D     SI1
# 53937   0.70  Very Good     D     SI1
# 53938   0.86    Premium     H     SI2
# 53939   0.75      Ideal     D     SI2
#
# [53940 rows x 4 columns]

# %%
diamonds_specific_cols = pd.read_csv("data/diamonds.csv",usecols=['carat','cut','color','clarity'])

# %%
diamonds_specific_cols
# Out:
#        carat        cut color clarity
# 0       0.23      Ideal     E     SI2
# 1       0.21    Premium     E     SI1
# 2       0.23       Good     E     VS1
# 3       0.29    Premium     I     VS2
# 4       0.31       Good     J     SI2
# ...      ...        ...   ...     ...
# 53935   0.72      Ideal     D     SI1
# 53936   0.72       Good     D     SI1
# 53937   0.70  Very Good     D     SI1
# 53938   0.86    Premium     H     SI2
# 53939   0.75      Ideal     D     SI2
#
# [53940 rows x 4 columns]

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds_df.head(3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
diamonds_df.head(30)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %%
diamonds_df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
diamonds_df.shape
# Out:
# (53940, 10)

# %%
diamonds_df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
diamonds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
diamonds_cut_df = diamonds_df['cut']

# %%
diamonds_cut_df
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
diamonds_low_df = diamonds_df.loc[diamonds_df['cut']=='Ideal']

# %%
diamonds_low_df
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z
# 0       0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 11      0.23  Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 13      0.31  Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 16      0.30  Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 39      0.33  Ideal     I     SI2   61.8   55.0    403  4.49  4.51  2.78
# ...      ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53925   0.79  Ideal     I     SI1   61.6   56.0   2756  5.95  5.97  3.67
# 53926   0.71  Ideal     E     SI1   61.9   56.0   2756  5.71  5.73  3.54
# 53929   0.71  Ideal     G     VS1   61.4   56.0   2756  5.76  5.73  3.53
# 53935   0.72  Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53939   0.75  Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [21551 rows x 10 columns]

# %%
diamonds_df['price_per_carat'] = diamonds_df['price']/diamonds_df['carat']

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_per_carat
# 0      1417.391304
# 1      1552.380952
# 2      1421.739130
# 3      1151.724138
# 4      1080.645161

# %%
import numpy as np
diamonds_df['price_per_carat_is_high'] = np.where(diamonds_df['price_per_carat']>3500,1,0)

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high
# 0      1417.391304                        0
# 1      1552.380952                        0
# 2      1421.739130                        0
# 3      1151.724138                        0
# 4      1080.645161                        0

# %%
diamonds_df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        price_per_carat  price_per_carat_is_high
# 53935      3829.166667                        1
# 53936      3829.166667                        1
# 53937      3938.571429                        1
# 53938      3205.813953                        0
# 53939      3676.000000                        1

# %%
diamonds_df['price']=diamonds_df['price']*1.3

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  423.8  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  423.8  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  425.1  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  434.2  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  435.5  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high
# 0      1417.391304                        0
# 1      1552.380952                        0
# 2      1421.739130                        0
# 3      1151.724138                        0
# 4      1080.645161                        0

# %%
import math
diamonds_df['rounded_price']=diamonds_df['price'].apply(math.ceil)

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  423.8  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  423.8  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  425.1  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  434.2  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  435.5  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high  rounded_price
# 0      1417.391304                        0            424
# 1      1552.380952                        0            424
# 2      1421.739130                        0            426
# 3      1151.724138                        0            435
# 4      1080.645161                        0            436

# %%
diamonds_df['rounded_price_to_100multiple']=diamonds_df['price'].apply(lambda x: math.ceil(x/100)*100)

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  423.8  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  423.8  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  425.1  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  434.2  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  435.5  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high  rounded_price  \
# 0      1417.391304                        0            424
# 1      1552.380952                        0            424
# 2      1421.739130                        0            426
# 3      1151.724138                        0            435
# 4      1080.645161                        0            436
#
#    rounded_price_to_100multiple
# 0                           500
# 1                           500
# 2                           500
# 3                           500
# ...

# %%
def is_desired(x):
    bool_var = 'yes' if (x['cut']=='Ideal' and x['color']=='D') else 'no'
    return bool_var

# %%
diamonds_df['desired']=diamonds_df.apply(is_desired, axis=1)

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  423.8  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  423.8  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  425.1  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  434.2  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  435.5  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high  rounded_price  \
# 0      1417.391304                        0            424
# 1      1552.380952                        0            424
# 2      1421.739130                        0            426
# 3      1151.724138                        0            435
# 4      1080.645161                        0            436
#
#    rounded_price_to_100multiple desired
# 0                           500      no
# 1                           500      no
# 2                           500      no
# ...

# %%
diamonds_df=diamonds_df.drop(columns=['rounded_price','rounded_price_to_100multiple','desired'])

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  423.8  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  423.8  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  425.1  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  434.2  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  435.5  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high
# 0      1417.391304                        0
# 1      1552.380952                        0
# 2      1421.739130                        0
# 3      1151.724138                        0
# 4      1080.645161                        0

# %%
diamonds_df.to_csv('diamonds_modifiedA.csv')

# %%
diamonds_df.to_csv('diamonds_modifiedB.csv',index=False)
